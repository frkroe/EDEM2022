# %% [markdown]
# # Predicción de Exitus (fallecimiento). Comparativa final

# %%
# Load Libraries
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import pandas as pd 
import multiprocessing
import random
from sklearn.metrics import roc_auc_score as metric




from sklearn.preprocessing import scale
from sklearn.preprocessing import OneHotEncoder
import timeit

# %% [markdown]
# ## Dataset

# %% [markdown]
# Leamos el dataset a utilizar.

# %%
# Load the dataset 
X = pd.read_csv("../datasets/dat_sanidad.csv", sep=';', decimal=',', encoding='latin-1')
X.shape
# Out:
# (32706, 10)

# %% [markdown]
# El dataset consta de:
#
# - 32706 **filas** o instancias
# - 10 **columnas** o variables.
#
# Veamos su contenido.

# %%
X.head()
# Out:
#    gravedad  pct_mortalidad_norma  edad_dias  numproc  potencial_ambul  proc  \
# 0         4              0.408730      12596       21                0     1
# 1         4              0.306931      20973       22                0     1
# 2         4              0.278481      19611       19                0     1
# 3         3              0.150289      13583       22                0     1
# 4         1              0.016573      18042        2                0     1
#
#    estancia_esperada tipgrd  tiping  exitus
# 0                151      Q       1       0
# 1                 99      Q       1       0
# 2                 87      Q       1       0
# 3                100      Q       1       0
# 4                 44      Q       1       0

# %% [markdown]
# - **gravedad**: Gravedad dentro del GRD. Valores de 1 a 4.
#
# - **pct_mortalidad_norma**: Tasa de mortalidad histórica para ese GRD.
#
# - **edad_dias**: Edad en días del paciente.
#
# - **numproc**: Número de procedimientos que se han llevado a cabo al paciente a las 24 horas.
#
# - **potencial_ambul**: Flag (valor 0 = no / 1 = sí) que indica si el caso se ha catalogado como potencialmente ambulatorio, es decir, no requiere ingreso.
#
# - **proc**: Procedencia del paciente.
#
# - **estancia_esperada**: Número de días que se espera que el paciente esté ingresado en el hospital por este episodio asistencial.
#
# - **tipgrd**: GRD médico (M) o de quirófano (Q).
#
# - **tiping**: Tipo de ingreso: Programado, urgente...
#
# - **exitus**: 1 = El paciente falleció.
#
# De estas variables, fecing la usaremos para realizar el split en train/validacion/test, exitus es el target y las 10 variables restantes serán el input de nuestro modelo.

# %% [markdown]
# ## Pre-procesado

# %% [markdown]
# ### One-Hot Encoding

# %% [markdown]
# Utilizaremos la técnica de one-hot encoding.
#
# <img src="../figures/oh.png" width="50%">

# %% [markdown]
# Seleccionemos las variables categóricas en primer lugar.

# %%
categorical_vars = set(['gravedad', 'proc', 'tiping', 'tipgrd'])
numerical_vars = set(X.columns) - categorical_vars
categorical_vars = list(categorical_vars)
numerical_vars = list(numerical_vars)

# %%
print(categorical_vars)
print(numerical_vars)
# Out:
# ['gravedad', 'tipgrd', 'tiping', 'proc']
# ['numproc', 'exitus', 'pct_mortalidad_norma', 'estancia_esperada', 'edad_dias', 'potencial_ambul']

# %% [markdown]
# Realizamos one hot encoding de las variables categoricas

# %%
ohe = OneHotEncoder(sparse = False)
ohe_fit = ohe.fit(X[categorical_vars])
X_ohe = pd.DataFrame(ohe.fit_transform(X[categorical_vars]))
X_ohe.columns = pd.DataFrame(ohe_fit.get_feature_names())

# %% [markdown]
# Volvemos a pegar las variables numéricas.

# %%
X = pd.concat((X_ohe, X[numerical_vars].reset_index()), axis=1)
del X['index']

# %% [markdown]
# ### Tipificar

# %% [markdown]
# Ahora vamos a tipificar los datos, es decir, llevarlos a media 0 y desviación estándar 1.

# %% [markdown]
# <img src="../figures/tipify.png" width="50%">

# %%
y = X['exitus']
del X['exitus']

# %%
X_scale = pd.DataFrame(scale(X))
X_scale.columns = X.columns
X = X_scale
X.columns = X_scale.columns
print(X.head())
# Out:
#     (x0_1,)   (x0_2,)   (x0_3,)   (x0_4,)   (x1_M,)   (x1_Q,)   (x2_1,)  \
# 0 -1.322185 -0.435743 -0.417921  4.120705 -1.554964  1.554964  0.589285
# 1 -1.322185 -0.435743 -0.417921  4.120705 -1.554964  1.554964  0.589285
# 2 -1.322185 -0.435743 -0.417921  4.120705 -1.554964  1.554964  0.589285
# 3 -1.322185 -0.435743  2.392797 -0.242677 -1.554964  1.554964  0.589285
# 4  0.756324 -0.435743 -0.417921 -0.242677 -1.554964  1.554964  0.589285
#
#    (x2_2,)   (x2_3,)   (x3_1,)  ...   (x3_4,)   (x3_6,)   (x3_7,)   (x3_8,)  \
# 0  -0.5681 -0.118114  0.589002  ... -0.140259 -0.118114 -0.009578 -0.134718
# 1  -0.5681 -0.118114  0.589002  ... -0.140259 -0.118114 -0.009578 -0.134718
# 2  -0.5681 -0.118114  0.589002  ... -0.140259 -0.118114 -0.009578 -0.134718
# 3  -0.5681 -0.118114  0.589002  ... -0.140259 -0.118114 -0.009578 -0.134718
# 4  -0.5681 -0.118114  0.589002  ... -0.140259 -0.118114 -0.009578 -0.134718
#
#     (x3_9,)   numproc  pct_mortalidad_norma  estancia_esperada  edad_dias  \
# 0 -0.090724  6.002393              5.678791          19.632898  -0.713484
# 1 -0.090724  6.357038              4.151382          12.641211   0.186170
# 2 -0.090724  5.293102              3.724521          11.027745   0.039897
# 3 -0.090724  6.357038              1.801116          12.775667  -0.607484
# 4 -0.090724 -0.735868             -0.205167           5.246158  -0.128607
#
#    potencial_ambul
# 0        -0.258527
# 1        -0.258527
# 2        -0.258527
# 3        -0.258527
# 4        -0.258527
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Split en Train/Validación/Test

# %% [markdown]
# Utilizaremos a modo de ejemplo los ratios habitualmente recomendados:
#
# • Train: 70%.
#
# • Validación: 15%.
#
# • Test: 15%.

# %%
perc_values = [0.7, 0.15, 0.15];

# %% [markdown]
# Creamos los conjuntos de train, validacion y test con el tamaño seleccionado pero respetando el eje temporal.

# %%
# dimensiones de los conjuntos de train y test
n_train = int(X.shape[0] * perc_values[0])
n_val = int(X.shape[0] * perc_values[1])
n_test = int(X.shape[0] * perc_values[2])

# selección del conjunto de train
X_train = X.iloc[:n_train]
y_train = y.iloc[:n_train]

# selección del conjunto de validación
X_val = X.iloc[(n_train):(n_train+n_val)]
y_val = y.iloc[(n_train):(n_train+n_val)]

# selección del conjunto de test
X_test = X.iloc[(n_train+n_val):]
y_test = y.iloc[(n_train+n_val):]

# %% [markdown]
# Visualizamos el tamaño de los 3 subdatasets

# %%
print('Train data size = ' + str(X_train.shape))
print('Train target size = ' + str(y_train.shape))
print('Validation data size = ' + str(X_val.shape))
print('Validation target size = ' + str(y_val.shape))
print('Test data size = ' + str(X_test.shape))
print('Test target size = ' + str(y_test.shape))
# Out:
# Train data size = (22894, 22)
# Train target size = (22894,)
# Validation data size = (4905, 22)
# Validation target size = (4905,)
# Test data size = (4907, 22)
# Test target size = (4907,)

# %% [markdown]
# # Grid Search

# %% [markdown]
# Vamos a proceder a realizar un grid search que compare todos los modelos de clasificación que hemos visto, es decir:
#
# ![imagen.png](attachment:imagen.png)

# %% [markdown]
# Importamos todos los modelos que vamos a usar.

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier

# %% [markdown]
# Importamos la métrica, en este caso AUC.

# %%
from sklearn.metrics import roc_auc_score as metric;

# %% [markdown]
# Definimos algunos parámetros generales.

# %%
random_state = 1;
nthread = multiprocessing.cpu_count() - 1;
scale_pos_weight = sum(y_train == 0) / sum(y_train == 1);

# %% [markdown]
# Vamos a calcular los puntos recomendados por Cherkassky para la SVM.

# %%
n = X_train.shape[0];
d = X_train.shape[1];
m = np.mean(y_train);
s = np.std(y_train);
C_cherk = np.max([np.abs(m + 3*s),np.abs(m - 3*s)]);
gamma_cherk = np.power(0.2, 1/d)

# %% [markdown]
# Definimos el grid a llevar a cabo

# %%
# Regresion Logística
regularization_values = ['l1', 'l2', 'none'];
penalty_values = [1, 10, 100];

# SVM
C_values = [C_cherk, 5e-03, 4.5e-03, 4e-03];
gamma_kernel_values = [gamma_cherk, 3.26e-09, 3.255e-09, 3.25e-09];

# Arbol de Decision
max_depth_values = [None, 6, 20];
min_samples_split_values = [2, 5, 20];
min_samples_leaf_values = [1, 5, 20];
max_features_values = [None, 1, 2];

# Random Forest
ntrees_values = [10, 100, 1000];

# Xgboost
nrounds_values = [10, 100]
eta_values = [0.3, 0.99]
gamma_values = [0, 1]
max_depth_values = [6, 20]
min_child_weight_values = [1, 20]
subsample_values = [0.1, 1]
colsample_bytree_values = [0.1, 1]
num_parallel_tree_values = [1, 20]
lambda_values = [0, 1]
alpha_values = [0, 1]

# %%
params_values = [{'model': 'logistic regression',
                  'regularization': regularization_values,
                 'penalty': penalty_values},
                 {'model': 'svm',
                  'C': C_values,
                 'gamma_kernel': gamma_kernel_values},
                 {'model': 'decision tree',
                 'max_depth': max_depth_values,
                 'min_samples_split': min_samples_split_values,
                 'min_samples_leaf': min_samples_leaf_values,
                 'max_features': max_features_values},
                 {'model': 'random forest',
                  'n_trees': ntrees_values,
                 'max_depth': max_depth_values,
                 'min_samples_split': min_samples_split_values,
                 'min_samples_leaf': min_samples_leaf_values,
                 'max_features': max_features_values},
                 {'model': 'xgboost',
                  'nrounds': nrounds_values,
                  'eta': eta_values,
                 'gamma': gamma_values,
                 'max_depth': max_depth_values,
                 'min_child_weight': min_child_weight_values,
                 'subsample': subsample_values,
                 'colsample_bytree': colsample_bytree_values,
                 'num_parallel_tree': num_parallel_tree_values,
                 'lambda': lambda_values,
                 'alpha': alpha_values}]

# %%
total_iteraciones = 0
for params in params_values:
    if params['model'] == 'logistic regression':
        n = len(params['regularization'])*len(params['penalty'])
    elif params['model'] == 'svm':
        n = len(params['C'])*len(params['gamma_kernel'])
    elif params['model'] == 'decision tree':
        n = len(params['max_depth'])*len(params['min_samples_split'])*len(params['min_samples_leaf'])*len(params['max_features'])
    elif params['model'] == 'random forest':
        n = len(params['n_trees'])*len(params['max_depth'])*len(params['min_samples_split'])*len(params['min_samples_leaf'])*len(params['max_features'])
    elif params['model'] == 'xgboost':
        n = len(params['nrounds'])*len(params['eta'])*len(params['gamma'])*len(params['max_depth'])*len(params['min_child_weight'])*len(params['subsample'])*len(params['colsample_bytree'])*len(params['num_parallel_tree'])*len(params['lambda'])*len(params['alpha'])
    total_iteraciones = total_iteraciones + n;
    print(str(n)+ ' iteraciones de ' + str(params['model']))
print(str(total_iteraciones)+ ' iteraciones en total')
# Out:
# 9 iteraciones de logistic regression
# 16 iteraciones de svm
# 54 iteraciones de decision tree
# 162 iteraciones de random forest
# 1024 iteraciones de xgboost
# 1265 iteraciones en total

# %%
grid_results = pd.DataFrame();
num_iter = 0
for params in params_values:
    
    
    # Logistic Regression
    if params['model'] == 'logistic regression':
        for regularization in params['regularization']:
            for penalty in params['penalty']:  
                start = timeit.default_timer()
                
                # Actualizar contador
                num_iter += 1; 
                
                # print control iteracion modelo
                print('Inicio de iteracion ' + str(num_iter) + 
                      '. Regularizacion = ' + str(regularization) + 
                      ', Lambda = '  + str(penalty) +
                      '\n')
                
                # Entrenar modelo
                if regularization == 'l1':
                    model = LogisticRegression(penalty = regularization, solver = 'liblinear', C = penalty, random_state = random_state)
                else:
                    model = LogisticRegression(penalty = regularization,solver = 'lbfgs', C = penalty, random_state = random_state)
               
                model.fit(X_train, np.array(y_train))

                # Generar predicciones
                pred_train_p = model.predict_proba(X_train)
                pred_val_p = model.predict_proba(X_val)

                # Calcular métricas de evaluación
                auc_train = metric(y_train, pred_train_p[:, 1])
                auc_val = metric(y_val, pred_val_p[:, 1])
                time = timeit.default_timer() - start

                print('Fin de iteracion ' + str(num_iter) + 
                     '. Regularizacion = ' + str(regularization) + 
                      ', Lambda = '  + str(penalty) +
                      '. AUC train = '  + str(auc_train) + 
                      ' -  AUC val = '  + str(auc_val)  + 
                      ' -  time = '  + str(time)  +
                      '\n')
                grid_results = grid_results.append(pd.DataFrame(data={'model':'Logistic Regression',
                                                                      'params': [{'regularization':[regularization],
                                                                                  'penalty':[penalty]}],
                                                                      'auc_train':[auc_train],
                                                                      'auc_val':[auc_val],
                                                                      'time':[time]},
                                                               columns=['model','params', 'auc_train', 'auc_val', 'time']), 
                                                   ignore_index=True)
                
     
    # SVM
    if params['model'] == 'svm':
        for C in params['C']:
            for gamma_kernel in params['gamma_kernel']:  
                start = timeit.default_timer()
                
                # Actualizar contador
                num_iter += 1; 
                
                # print control iteracion modelo
                print('Inicio de iteracion ' + str(num_iter) + 
                      '. C = ' + str(C) + 
                      ', gamma = '  + str(gamma_kernel) +
                      '\n')
                
                # Entrenar modelo               
                model = SVC(C = C, gamma = gamma_kernel, probability = True, random_state = random_state)
               
                model.fit(X_train, np.array(y_train))

                # Generar predicciones
                pred_train_p = model.predict_proba(X_train)
                pred_val_p = model.predict_proba(X_val)

                # Calcular métricas de evaluación
                auc_train = metric(y_train, pred_train_p[:, 1])
                auc_val = metric(y_val, pred_val_p[:, 1])
                time = timeit.default_timer() - start

                print('Fin de iteracion ' + str(num_iter) + 
                     '. C = ' + str(C) + 
                      ', gamma = '  + str(gamma_kernel) +
                      '. AUC train = '  + str(auc_train) + 
                      ' -  AUC val = '  + str(auc_val)  + 
                      ' -  time = '  + str(time)  +
                      '\n')
                grid_results = grid_results.append(pd.DataFrame(data={'model':'SVM',
                                                                     'params': [{'C':[C],
                                                                              'gamma_kernel':[gamma_kernel]}],
                                                                      'auc_train':[auc_train],
                                                                      'auc_val':[auc_val],
                                                                      'time':[time]},
                                                               columns=['model','params', 'auc_train', 'auc_val', 'time']), 
                                                   ignore_index=True)
                
    # Decision Tree
    if params['model'] == 'decision tree':
        for max_depth in params['max_depth']:
            for min_samples_split in params['min_samples_split']:  
                for min_samples_leaf in params['min_samples_leaf']:  
                    for max_features in params['max_features']:  
                        start = timeit.default_timer()
                
                        # Actualizar contador
                        num_iter += 1; 

                        # print control iteracion modelo
                        print('Inicio de iteracion ' + str(num_iter) + 
                              '. max_depth = ' + str(max_depth) + 
                              ', min_samples_split = '  + str(min_samples_split) +
                              ', min_samples_leaf = '  + str(min_samples_leaf) +
                              ', max_features = '  + str(max_features) +
                              '\n')

                        # Entrenar modelo               
                        model = DecisionTreeClassifier(max_depth = max_depth,
                                                      min_samples_split = min_samples_split,
                                                      min_samples_leaf = min_samples_leaf,
                                                      max_features = max_features, random_state = random_state)

                        model.fit(X_train, np.array(y_train))

                        # Generar predicciones
                        pred_train_p = model.predict_proba(X_train)
                        pred_val_p = model.predict_proba(X_val)

                        # Calcular métricas de evaluación
                        auc_train = metric(y_train, pred_train_p[:, 1])
                        auc_val = metric(y_val, pred_val_p[:, 1])
                        time = timeit.default_timer() - start

                        print('Fin de iteracion ' + str(num_iter) + 
                             '. max_depth = ' + str(max_depth) + 
                              ', min_samples_split = '  + str(min_samples_split) +
                              ', min_samples_leaf = '  + str(min_samples_leaf) +
                              ', max_features = '  + str(max_features) +
                              '. AUC train = '  + str(auc_train) + 
                              ' -  AUC val = '  + str(auc_val)  + 
                              ' -  time = '  + str(time)  +
                              '\n')
                        grid_results = grid_results.append(pd.DataFrame(data={'model':'decision tree',
                                                                              'params': [{'max_depth':[max_depth],
                                                                                          'min_samples_split':[min_samples_split],
                                                                                          'min_samples_leaf':[min_samples_leaf],
                                                                                          'max_features':[max_features]}],
                                                                      'auc_train':[auc_train],
                                                                      'auc_val':[auc_val],
                                                                      'time':[time]},
                                                                       columns=['model','params', 'auc_train', 'auc_val', 'time']), 
                                                           ignore_index=True)  
                        
    
    # Random Forest
    if params['model'] == 'random forest':
        for n_trees in params['n_trees']:
            for max_depth in params['max_depth']:
                for min_samples_split in params['min_samples_split']:  
                    for min_samples_leaf in params['min_samples_leaf']:  
                        for max_features in params['max_features']:  
                            start = timeit.default_timer()
                
                            # Actualizar contador
                            num_iter += 1; 

                            # print control iteracion modelo
                            print('Inicio de iteracion ' + str(num_iter) + 
                                  '. n_trees = ' + str(n_trees) + 
                                  ', max_depth = ' + str(max_depth) + 
                                  ', min_samples_split = '  + str(min_samples_split) +
                                  ', min_samples_leaf = '  + str(min_samples_leaf) +
                                  ', max_features = '  + str(max_features) +
                                  '\n')

                            # Entrenar modelo               
                            model = RandomForestClassifier(n_estimators = n_trees,
                                                          max_depth = max_depth,
                                                          min_samples_split = min_samples_split,
                                                          min_samples_leaf = min_samples_leaf,
                                                          max_features = max_features, random_state = random_state)

                            model.fit(X_train, np.array(y_train))

                            # Generar predicciones
                            pred_train_p = model.predict_proba(X_train)
                            pred_val_p = model.predict_proba(X_val)

                            # Calcular métricas de evaluación
                            auc_train = metric(y_train, pred_train_p[:, 1])
                            auc_val = metric(y_val, pred_val_p[:, 1])  
                            time = timeit.default_timer() - start

                            print('Fin de iteracion ' + str(num_iter) + 
                                 '. n_trees = ' + str(n_trees) + 
                                  ', max_depth = ' + str(max_depth) + 
                                  ', min_samples_split = '  + str(min_samples_split) +
                                  ', min_samples_leaf = '  + str(min_samples_leaf) +
                                  ', max_features = '  + str(max_features) +
                                  '. AUC train = '  + str(auc_train) + 
                                  ' -  AUC val = '  + str(auc_val)  + 
                                  ' -  time = '  + str(time)  +
                                  '\n')
                            grid_results = grid_results.append(pd.DataFrame(data={'model':'random forest',
                                                                                  'params': [{'n_trees':[n_trees],
                                                                                              'max_depth':[max_depth],
                                                                                              'min_samples_split':[min_samples_split],
                                                                                              'min_samples_leaf':[min_samples_leaf],
                                                                                              'max_features':[max_features]}],
                                                                          'auc_train':[auc_train],
                                                                          'auc_val':[auc_val],
                                                                          'time':[time]},
                                                                           columns=['model','params', 'auc_train', 'auc_val', 'time']), 
                                                               ignore_index=True)  
    
    # XGBOOST
    if params['model'] == 'xgboost':
         for nrounds in params['nrounds']:
            for eta in params['eta']:
                for gamma in params['gamma']:
                    for max_depth in params['max_depth']:
                        for min_child_weight in params['min_child_weight']:
                            for subsample in params['subsample']:
                                for colsample_bytree in params['colsample_bytree']:
                                    for num_parallel_tree in params['num_parallel_tree']:
                                        for lamda in params['lambda']:
                                            for alpha in params['alpha']:
                                                start = timeit.default_timer()
                                            
                                                # Actualizar contador
                                                num_iter += 1; 

                                                # print control iteracion modelo
                                                print('Inicio de iteracion ' + str(num_iter) + 
                                                      '. Parametro nrounds = ' + str(nrounds) + 
                                                      ', parametro eta = '  + str(eta) +
                                                      ', parametro gamma = '  + str(gamma) +
                                                      ', parametro max_depth = '  + str(max_depth) +
                                                      ', parametro min_child_weight = '  + str(min_child_weight) +
                                                      ', parametro subsample = '  + str(subsample) +
                                                      ', parametro colsample_bytree = '  + str(colsample_bytree) +
                                                      ', parametro num_parallel_tree = '  + str(num_parallel_tree) +
                                                      ', parametro lambda = '  + str(lamda) +
                                                      ', parametro alpha = '  + str(alpha) + 
                                                      '\n')
                                                # Entrenar modelo
                                                model = XGBClassifier(nthread = nthread, 
                                                                      scale_pos_weight = scale_pos_weight,
                                                                      random_state = random_state,
                                                                      n_estimators = nrounds,
                                                                      learning_rate = eta, 
                                                                      gamma = gamma,
                                                                      max_depth = max_depth,
                                                                      min_child_weight = min_child_weight ,
                                                                      subsample = subsample,
                                                                      colsample_bytree = colsample_bytree,
                                                                      num_parallel_tree = num_parallel_tree,
                                                                      reg_lambda = lamda,
                                                                      reg_alpha = alpha)
                                                model.fit(X_train, np.array(y_train))

                                                # Generar predicciones
                                                pred_train_p = model.predict_proba(X_train)
                                                pred_val_p = model.predict_proba(X_val)

                                                # Calcular métricas de evaluación
                                                auc_train = metric(y_train, pred_train_p[:, 1])
                                                auc_val = metric(y_val, pred_val_p[:, 1])    
                                                time = timeit.default_timer() - start

                                                print('Fin de iteracion ' + str(num_iter) + 
                                                      '. Parametro nrounds = ' + str(nrounds) + 
                                                      ', parametro eta = ' + str(eta) + 
                                                      ', parametro gamma = '  + str(gamma) +
                                                      ', parametro max_depth = '  + str(max_depth) +
                                                      ', parametro min_child_weight = '  + str(min_child_weight) +
                                                      ', parametro subsample = '  + str(subsample) +
                                                      ', parametro colsample_bytree = '  + str(colsample_bytree) +
                                                      ', parametro num_parallel_tree = '  + str(num_parallel_tree) +
                                                      ', parametro lambda = '  + str(lamda) +
                                                      ', parametro alpha = '  + str(alpha) + 
                                                      '. AUC train = '  + str(auc_train) + 
                                                      ' -  AUC val = '  + str(auc_val)  + 
                                                      ' -  time = '  + str(time)  +
                                                      '\n')
                                                grid_results = grid_results.append(pd.DataFrame(data={'model':'xgboost',
                                                                                              'params': [{'nrounds':[nrounds],
                                                                                              'eta':[eta],
                                                                                              'gamma':[gamma],
                                                                                              'max_depth':[max_depth],
                                                                                              'min_child_weight':[min_child_weight],
                                                                                              'subsample':[subsample],
                                                                                              'colsample_bytree':[colsample_bytree],
                                                                                              'num_parallel_tree':[num_parallel_tree],
                                                                                              'lamda':[lamda],
                                                                                              'alpha':[alpha]}],
                                                                                              'auc_train':[auc_train],
                                                                                              'auc_val':[auc_val],
                                                                                              'time':[time]},
                                                                                               columns=['model', 'params', 'auc_train', 'auc_val', 'time']), 
                                                                                   ignore_index=True)
# Out:
# Inicio de iteracion 1. Regularizacion = l1, Lambda = 1
#
# Fin de iteracion 1. Regularizacion = l1, Lambda = 1. AUC train = 0.9405724879370099 -  AUC val = 0.9380497022446177 -  time = 0.9875566000000617
#
# Inicio de iteracion 2. Regularizacion = l1, Lambda = 10
#
# Fin de iteracion 2. Regularizacion = l1, Lambda = 10. AUC train = 0.9405197616896838 -  AUC val = 0.9378355474118185 -  time = 9.117578900000126
#
# Inicio de iteracion 3. Regularizacion = l1, Lambda = 100
#
# Fin de iteracion 3. Regularizacion = l1, Lambda = 100. AUC train = 0.9405133441814892 -  AUC val = 0.9376717819514431 -  time = 2.224766000000045
#
# Inicio de iteracion 4. Regularizacion = l2, Lambda = 1
#
# Fin de iteracion 4. Regularizacion = l2, Lambda = 1. AUC train = 0.9405310051640405 -  AUC val = 0.9384264773247823 -  time = 0.16193589999988944
#
# Inicio de iteracion 5. Regularizacion = l2, Lambda = 10
#
# Fin de iteracion 5. Regularizacion = l2, Lambda = 10. AUC train = 0.9405154491241771 -  AUC val = 0.9389509848831882 -  time = 0.166268700000046
#
# Inicio de iteracion 6. Regularizacion = l2, Lambda = 100
#
# Fin de iteracion 6. Regularizacion = l2, Lambda = 100. AUC train = 0.9405136008818171 -  AUC val = 0.9389017407237745 -  time = 0.1796640000000025
#
# Inicio de iteracion 7. Regularizacion = none, Lambda = 1
#
# Fin de iteracion 7. Regularizacion = none, Lambda = 1. AUC train = 0.940510931198408 -  AUC val = 0.9388811268896015 -  time = 0.16264960000012252
#
# Inicio de iteracion 8. Regularizacion = none, Lambda = 10
# C:\Users\jesus\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\jesus\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1322: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\jesus\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\jesus\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1322: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# Fin de iteracion 8. Regularizacion = none, Lambda = 10. AUC train = 0.940510931198408 -  AUC val = 0.9388811268896015 -  time = 0.1670560000000023
#
# Inicio de iteracion 9. Regularizacion = none, Lambda = 100
# C:\Users\jesus\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Fin de iteracion 9. Regularizacion = none, Lambda = 100. AUC train = 0.940510931198408 -  AUC val = 0.9388811268896015 -  time = 0.18714609999983622
#
# Inicio de iteracion 10. C = 0.6169806179116835, gamma = 0.9294555738186685
#
# Fin de iteracion 10. C = 0.6169806179116835, gamma = 0.9294555738186685. AUC train = 0.8880951885887463 -  AUC val = 0.7195379065506186 -  time = 23.633340999999973
#
# Inicio de iteracion 11. C = 0.6169806179116835, gamma = 3.26e-09
#
# Fin de iteracion 11. C = 0.6169806179116835, gamma = 3.26e-09. AUC train = 0.9380300252105392 -  AUC val = 0.9377565277141547 -  time = 10.678205700000035
#
# Inicio de iteracion 12. C = 0.6169806179116835, gamma = 3.255e-09
#
# Fin de iteracion 12. C = 0.6169806179116835, gamma = 3.255e-09. AUC train = 0.93880510618024 -  AUC val = 0.9386486486486486 -  time = 10.639755700000023
#
# Inicio de iteracion 13. C = 0.6169806179116835, gamma = 3.25e-09
#
# Fin de iteracion 13. C = 0.6169806179116835, gamma = 3.25e-09. AUC train = 0.9393458197506773 -  AUC val = 0.9387127805771873 -  time = 10.662136600000167
#
# Inicio de iteracion 14. C = 0.005, gamma = 0.9294555738186685
#
# Fin de iteracion 14. C = 0.005, gamma = 0.9294555738186685. AUC train = 0.844666524454685 -  AUC val = 0.7233216903344022 -  time = 15.532507899999928
#
# Inicio de iteracion 15. C = 0.005, gamma = 3.26e-09
#
# Fin de iteracion 15. C = 0.005, gamma = 3.26e-09. AUC train = 0.9371579628570027 -  AUC val = 0.9386761337608795 -  time = 11.446580499999982
#
# Inicio de iteracion 16. C = 0.005, gamma = 3.255e-09
#
# Fin de iteracion 16. C = 0.005, gamma = 3.255e-09. AUC train = 0.9378672258626607 -  AUC val = 0.9385948236371966 -  time = 11.75917789999994
#
# Inicio de iteracion 17. C = 0.005, gamma = 3.25e-09
#
# Fin de iteracion 17. C = 0.005, gamma = 3.25e-09. AUC train = 0.9387096906684042 -  AUC val = 0.9385971140632158 -  time = 12.037164699999948
#
# Inicio de iteracion 18. C = 0.0045, gamma = 0.9294555738186685
#
# Fin de iteracion 18. C = 0.0045, gamma = 0.9294555738186685. AUC train = 0.8074090388806018 -  AUC val = 0.6424696518552451 -  time = 17.24107120000008
#
# Inicio de iteracion 19. C = 0.0045, gamma = 3.26e-09
#
# Fin de iteracion 19. C = 0.0045, gamma = 3.26e-09. AUC train = 0.9380594687381357 -  AUC val = 0.9391468163078333 -  time = 13.502938500000027
#
# Inicio de iteracion 20. C = 0.0045, gamma = 3.255e-09
#
# Fin de iteracion 20. C = 0.0045, gamma = 3.255e-09. AUC train = 0.9382312782675193 -  AUC val = 0.9383749427393494 -  time = 11.362373299999945
#
# Inicio de iteracion 21. C = 0.0045, gamma = 3.25e-09
#
# Fin de iteracion 21. C = 0.0045, gamma = 3.25e-09. AUC train = 0.9383065941436901 -  AUC val = 0.9385432890517637 -  time = 10.728529499999922
#
# Inicio de iteracion 22. C = 0.004, gamma = 0.9294555738186685
#
# Fin de iteracion 22. C = 0.004, gamma = 0.9294555738186685. AUC train = 0.806074222846175 -  AUC val = 0.6683365781035272 -  time = 14.02313809999987
#
# Inicio de iteracion 23. C = 0.004, gamma = 3.26e-09
#
# Fin de iteracion 23. C = 0.004, gamma = 3.26e-09. AUC train = 0.937680861424692 -  AUC val = 0.9392258360054969 -  time = 10.406820700000026
#
# Inicio de iteracion 24. C = 0.004, gamma = 3.255e-09
#
# Fin de iteracion 24. C = 0.004, gamma = 3.255e-09. AUC train = 0.9373074651279021 -  AUC val = 0.9378034814475493 -  time = 10.553290999999945
#
# Inicio de iteracion 25. C = 0.004, gamma = 3.25e-09
#
# Fin de iteracion 25. C = 0.004, gamma = 3.25e-09. AUC train = 0.9387138748837469 -  AUC val = 0.9387688960146587 -  time = 10.756689599999845
#
# Inicio de iteracion 26. max_depth = 6, min_samples_split = 2, min_samples_leaf = 1, max_features = None
#
# Fin de iteracion 26. max_depth = 6, min_samples_split = 2, min_samples_leaf = 1, max_features = None. AUC train = 0.9528682539474734 -  AUC val = 0.9116468163078334 -  time = 0.040420099999892045
#
# Inicio de iteracion 27. max_depth = 6, min_samples_split = 2, min_samples_leaf = 1, max_features = 1
#
# Fin de iteracion 27. max_depth = 6, min_samples_split = 2, min_samples_leaf = 1, max_features = 1. AUC train = 0.9251163558410748 -  AUC val = 0.908891433806688 -  time = 0.01411380000013196
#
# Inicio de iteracion 28. max_depth = 6, min_samples_split = 2, min_samples_leaf = 1, max_features = 2
#
# Fin de iteracion 28. max_depth = 6, min_samples_split = 2, min_samples_leaf = 1, max_features = 2. AUC train = 0.9290977009148543 -  AUC val = 0.909192624828218 -  time = 0.017174099999920145
#
# Inicio de iteracion 29. max_depth = 6, min_samples_split = 2, min_samples_leaf = 5, max_features = None
#
# Fin de iteracion 29. max_depth = 6, min_samples_split = 2, min_samples_leaf = 5, max_features = None. AUC train = 0.9530335432885315 -  AUC val = 0.9044262482821805 -  time = 0.04053240000007463
#
# Inicio de iteracion 30. max_depth = 6, min_samples_split = 2, min_samples_leaf = 5, max_features = 1
#
# Fin de iteracion 30. max_depth = 6, min_samples_split = 2, min_samples_leaf = 5, max_features = 1. AUC train = 0.8787055269890874 -  AUC val = 0.8574496106275767 -  time = 0.01392149999992398
#
# Inicio de iteracion 31. max_depth = 6, min_samples_split = 2, min_samples_leaf = 5, max_features = 2
#
# Fin de iteracion 31. max_depth = 6, min_samples_split = 2, min_samples_leaf = 5, max_features = 2. AUC train = 0.9275360131307352 -  AUC val = 0.9078991067338525 -  time = 0.017430500000045868
#
# Inicio de iteracion 32. max_depth = 6, min_samples_split = 2, min_samples_leaf = 20, max_features = None
#
# Fin de iteracion 32. max_depth = 6, min_samples_split = 2, min_samples_leaf = 20, max_features = None. AUC train = 0.9519405132928415 -  AUC val = 0.9373505497022447 -  time = 0.040261699999973644
#
# Inicio de iteracion 33. max_depth = 6, min_samples_split = 2, min_samples_leaf = 20, max_features = 1
#
# Fin de iteracion 33. max_depth = 6, min_samples_split = 2, min_samples_leaf = 20, max_features = 1. AUC train = 0.9298624111913129 -  AUC val = 0.9072325927622538 -  time = 0.014152399999829868
#
# Inicio de iteracion 34. max_depth = 6, min_samples_split = 2, min_samples_leaf = 20, max_features = 2
#
# Fin de iteracion 34. max_depth = 6, min_samples_split = 2, min_samples_leaf = 20, max_features = 2. AUC train = 0.8614318025522687 -  AUC val = 0.8452748511223087 -  time = 0.01845010000010916
#
# Inicio de iteracion 35. max_depth = 6, min_samples_split = 5, min_samples_leaf = 1, max_features = None
#
# Fin de iteracion 35. max_depth = 6, min_samples_split = 5, min_samples_leaf = 1, max_features = None. AUC train = 0.9527901143676971 -  AUC val = 0.9118540998625746 -  time = 0.040803099999948245
#
# Inicio de iteracion 36. max_depth = 6, min_samples_split = 5, min_samples_leaf = 1, max_features = 1
#
# Fin de iteracion 36. max_depth = 6, min_samples_split = 5, min_samples_leaf = 1, max_features = 1. AUC train = 0.9247661652539164 -  AUC val = 0.9023808978469996 -  time = 0.013859600000159844
#
# Inicio de iteracion 37. max_depth = 6, min_samples_split = 5, min_samples_leaf = 1, max_features = 2
#
# Fin de iteracion 37. max_depth = 6, min_samples_split = 5, min_samples_leaf = 1, max_features = 2. AUC train = 0.9290977009148543 -  AUC val = 0.909192624828218 -  time = 0.017072099999950296
#
# Inicio de iteracion 38. max_depth = 6, min_samples_split = 5, min_samples_leaf = 5, max_features = None
#
# Fin de iteracion 38. max_depth = 6, min_samples_split = 5, min_samples_leaf = 5, max_features = None. AUC train = 0.9530335432885315 -  AUC val = 0.9044262482821805 -  time = 0.0404983999999331
#
# Inicio de iteracion 39. max_depth = 6, min_samples_split = 5, min_samples_leaf = 5, max_features = 1
#
# Fin de iteracion 39. max_depth = 6, min_samples_split = 5, min_samples_leaf = 5, max_features = 1. AUC train = 0.8787055269890874 -  AUC val = 0.8574496106275767 -  time = 0.013481499999898006
#
# Inicio de iteracion 40. max_depth = 6, min_samples_split = 5, min_samples_leaf = 5, max_features = 2
#
# Fin de iteracion 40. max_depth = 6, min_samples_split = 5, min_samples_leaf = 5, max_features = 2. AUC train = 0.9275360131307352 -  AUC val = 0.9078991067338525 -  time = 0.017277200000080484
#
# Inicio de iteracion 41. max_depth = 6, min_samples_split = 5, min_samples_leaf = 20, max_features = None
#
# Fin de iteracion 41. max_depth = 6, min_samples_split = 5, min_samples_leaf = 20, max_features = None. AUC train = 0.9519405132928415 -  AUC val = 0.9373505497022447 -  time = 0.0429569000000356
#
# Inicio de iteracion 42. max_depth = 6, min_samples_split = 5, min_samples_leaf = 20, max_features = 1
#
# Fin de iteracion 42. max_depth = 6, min_samples_split = 5, min_samples_leaf = 20, max_features = 1. AUC train = 0.9298624111913129 -  AUC val = 0.9072325927622538 -  time = 0.014613199999985227
#
# Inicio de iteracion 43. max_depth = 6, min_samples_split = 5, min_samples_leaf = 20, max_features = 2
#
# Fin de iteracion 43. max_depth = 6, min_samples_split = 5, min_samples_leaf = 20, max_features = 2. AUC train = 0.8614318025522687 -  AUC val = 0.8452748511223087 -  time = 0.01704620000009527
#
# Inicio de iteracion 44. max_depth = 6, min_samples_split = 20, min_samples_leaf = 1, max_features = None
#
# Fin de iteracion 44. max_depth = 6, min_samples_split = 20, min_samples_leaf = 1, max_features = None. AUC train = 0.9525775664962948 -  AUC val = 0.9118924644983969 -  time = 0.041942199999994045
#
# Inicio de iteracion 45. max_depth = 6, min_samples_split = 20, min_samples_leaf = 1, max_features = 1
#
# Fin de iteracion 45. max_depth = 6, min_samples_split = 20, min_samples_leaf = 1, max_features = 1. AUC train = 0.8970665826743194 -  AUC val = 0.8869955336692625 -  time = 0.012879899999916233
#
# Inicio de iteracion 46. max_depth = 6, min_samples_split = 20, min_samples_leaf = 1, max_features = 2
#
# Fin de iteracion 46. max_depth = 6, min_samples_split = 20, min_samples_leaf = 1, max_features = 2. AUC train = 0.9292640170572234 -  AUC val = 0.9102885936784242 -  time = 0.018090999999913038
#
# Inicio de iteracion 47. max_depth = 6, min_samples_split = 20, min_samples_leaf = 5, max_features = None
#
# Fin de iteracion 47. max_depth = 6, min_samples_split = 20, min_samples_leaf = 5, max_features = None. AUC train = 0.9528344721843376 -  AUC val = 0.90457856161246 -  time = 0.04124610000008033
#
# Inicio de iteracion 48. max_depth = 6, min_samples_split = 20, min_samples_leaf = 5, max_features = 1
#
# Fin de iteracion 48. max_depth = 6, min_samples_split = 20, min_samples_leaf = 5, max_features = 1. AUC train = 0.9308744265635552 -  AUC val = 0.9021203618873112 -  time = 0.013230399999883957
#
# Inicio de iteracion 49. max_depth = 6, min_samples_split = 20, min_samples_leaf = 5, max_features = 2
#
# Fin de iteracion 49. max_depth = 6, min_samples_split = 20, min_samples_leaf = 5, max_features = 2. AUC train = 0.9294304102096909 -  AUC val = 0.9097921438387541 -  time = 0.017555099999981394
#
# Inicio de iteracion 50. max_depth = 6, min_samples_split = 20, min_samples_leaf = 20, max_features = None
#
# Fin de iteracion 50. max_depth = 6, min_samples_split = 20, min_samples_leaf = 20, max_features = None. AUC train = 0.9519405132928415 -  AUC val = 0.9373505497022447 -  time = 0.04086030000007668
#
# Inicio de iteracion 51. max_depth = 6, min_samples_split = 20, min_samples_leaf = 20, max_features = 1
# Fin de iteracion 51. max_depth = 6, min_samples_split = 20, min_samples_leaf = 20, max_features = 1. AUC train = 0.9298624111913129 -  AUC val = 0.9072325927622538 -  time = 0.015138600000000224
#
# Inicio de iteracion 52. max_depth = 6, min_samples_split = 20, min_samples_leaf = 20, max_features = 2
#
# Fin de iteracion 52. max_depth = 6, min_samples_split = 20, min_samples_leaf = 20, max_features = 2. AUC train = 0.8614318025522687 -  AUC val = 0.8452748511223087 -  time = 0.018401000000039858
#
# Inicio de iteracion 53. max_depth = 20, min_samples_split = 2, min_samples_leaf = 1, max_features = None
#
# Fin de iteracion 53. max_depth = 20, min_samples_split = 2, min_samples_leaf = 1, max_features = None. AUC train = 0.9999183436257328 -  AUC val = 0.6360604672469079 -  time = 0.058718100000078266
#
# Inicio de iteracion 54. max_depth = 20, min_samples_split = 2, min_samples_leaf = 1, max_features = 1
#
# Fin de iteracion 54. max_depth = 20, min_samples_split = 2, min_samples_leaf = 1, max_features = 1. AUC train = 0.9995742625063758 -  AUC val = 0.6183096655978011 -  time = 0.018968200000017532
#
# Inicio de iteracion 55. max_depth = 20, min_samples_split = 2, min_samples_leaf = 1, max_features = 2
#
# Fin de iteracion 55. max_depth = 20, min_samples_split = 2, min_samples_leaf = 1, max_features = 2. AUC train = 0.9978284692471724 -  AUC val = 0.6746993815849748 -  time = 0.0211864999998852
#
# Inicio de iteracion 56. max_depth = 20, min_samples_split = 2, min_samples_leaf = 5, max_features = None
#
# Fin de iteracion 56. max_depth = 20, min_samples_split = 2, min_samples_leaf = 5, max_features = None. AUC train = 0.9881633168557393 -  AUC val = 0.7464051763628036 -  time = 0.05690879999997378
#
# Inicio de iteracion 57. max_depth = 20, min_samples_split = 2, min_samples_leaf = 5, max_features = 1
#
# Fin de iteracion 57. max_depth = 20, min_samples_split = 2, min_samples_leaf = 5, max_features = 1. AUC train = 0.974598552774892 -  AUC val = 0.8346696060467247 -  time = 0.01922570000010637
#
# Inicio de iteracion 58. max_depth = 20, min_samples_split = 2, min_samples_leaf = 5, max_features = 2
#
# Fin de iteracion 58. max_depth = 20, min_samples_split = 2, min_samples_leaf = 5, max_features = 2. AUC train = 0.9770100726641617 -  AUC val = 0.8022841273476866 -  time = 0.022139800000104515
#
# Inicio de iteracion 59. max_depth = 20, min_samples_split = 2, min_samples_leaf = 20, max_features = None
#
# Fin de iteracion 59. max_depth = 20, min_samples_split = 2, min_samples_leaf = 20, max_features = None. AUC train = 0.9686876940173165 -  AUC val = 0.8776431516262024 -  time = 0.05403569999998581
#
# Inicio de iteracion 60. max_depth = 20, min_samples_split = 2, min_samples_leaf = 20, max_features = 1
#
# Fin de iteracion 60. max_depth = 20, min_samples_split = 2, min_samples_leaf = 20, max_features = 1. AUC train = 0.9613005773447072 -  AUC val = 0.8918781493357765 -  time = 0.01758620000009614
#
# Inicio de iteracion 61. max_depth = 20, min_samples_split = 2, min_samples_leaf = 20, max_features = 2
#
# Fin de iteracion 61. max_depth = 20, min_samples_split = 2, min_samples_leaf = 20, max_features = 2. AUC train = 0.9481818557534116 -  AUC val = 0.8763479157123224 -  time = 0.02012079999985872
#
# Inicio de iteracion 62. max_depth = 20, min_samples_split = 5, min_samples_leaf = 1, max_features = None
#
# Fin de iteracion 62. max_depth = 20, min_samples_split = 5, min_samples_leaf = 1, max_features = None. AUC train = 0.9982448885188981 -  AUC val = 0.6701866697205681 -  time = 0.05770170000005237
#
# Inicio de iteracion 63. max_depth = 20, min_samples_split = 5, min_samples_leaf = 1, max_features = 1
#
# Fin de iteracion 63. max_depth = 20, min_samples_split = 5, min_samples_leaf = 1, max_features = 1. AUC train = 0.9936751349537798 -  AUC val = 0.7364870590929912 -  time = 0.020497199999908844
#
# Inicio de iteracion 64. max_depth = 20, min_samples_split = 5, min_samples_leaf = 1, max_features = 2
#
# Fin de iteracion 64. max_depth = 20, min_samples_split = 5, min_samples_leaf = 1, max_features = 2. AUC train = 0.9936947468588223 -  AUC val = 0.7218575355016035 -  time = 0.022847100000035425
#
# Inicio de iteracion 65. max_depth = 20, min_samples_split = 5, min_samples_leaf = 5, max_features = None
#
# Fin de iteracion 65. max_depth = 20, min_samples_split = 5, min_samples_leaf = 5, max_features = None. AUC train = 0.9881633168557393 -  AUC val = 0.7464051763628036 -  time = 0.05590839999990749
#
# Inicio de iteracion 66. max_depth = 20, min_samples_split = 5, min_samples_leaf = 5, max_features = 1
#
# Fin de iteracion 66. max_depth = 20, min_samples_split = 5, min_samples_leaf = 5, max_features = 1. AUC train = 0.974598552774892 -  AUC val = 0.8346696060467247 -  time = 0.02052019999996446
#
# Inicio de iteracion 67. max_depth = 20, min_samples_split = 5, min_samples_leaf = 5, max_features = 2
#
# Fin de iteracion 67. max_depth = 20, min_samples_split = 5, min_samples_leaf = 5, max_features = 2. AUC train = 0.9770100726641617 -  AUC val = 0.8022841273476866 -  time = 0.020608000000038373
#
# Inicio de iteracion 68. max_depth = 20, min_samples_split = 5, min_samples_leaf = 20, max_features = None
#
# Fin de iteracion 68. max_depth = 20, min_samples_split = 5, min_samples_leaf = 20, max_features = None. AUC train = 0.9686876940173165 -  AUC val = 0.8776431516262024 -  time = 0.053417000000081316
#
# Inicio de iteracion 69. max_depth = 20, min_samples_split = 5, min_samples_leaf = 20, max_features = 1
#
# Fin de iteracion 69. max_depth = 20, min_samples_split = 5, min_samples_leaf = 20, max_features = 1. AUC train = 0.9613005773447072 -  AUC val = 0.8918781493357765 -  time = 0.01937830000019858
#
# Inicio de iteracion 70. max_depth = 20, min_samples_split = 5, min_samples_leaf = 20, max_features = 2
#
# Fin de iteracion 70. max_depth = 20, min_samples_split = 5, min_samples_leaf = 20, max_features = 2. AUC train = 0.9481818557534116 -  AUC val = 0.8763479157123224 -  time = 0.025869999999940774
#
# Inicio de iteracion 71. max_depth = 20, min_samples_split = 20, min_samples_leaf = 1, max_features = None
#
# Fin de iteracion 71. max_depth = 20, min_samples_split = 20, min_samples_leaf = 1, max_features = None. AUC train = 0.9875815055628244 -  AUC val = 0.7798499770957398 -  time = 0.06806780000010804
#
# Inicio de iteracion 72. max_depth = 20, min_samples_split = 20, min_samples_leaf = 1, max_features = 1
#
# Fin de iteracion 72. max_depth = 20, min_samples_split = 20, min_samples_leaf = 1, max_features = 1. AUC train = 0.9804043184182741 -  AUC val = 0.7927782867613375 -  time = 0.0237601999999697
#
# Inicio de iteracion 73. max_depth = 20, min_samples_split = 20, min_samples_leaf = 1, max_features = 2
#
# Fin de iteracion 73. max_depth = 20, min_samples_split = 20, min_samples_leaf = 1, max_features = 2. AUC train = 0.9793672747640731 -  AUC val = 0.8198700183234082 -  time = 0.024710800000093514
#
# Inicio de iteracion 74. max_depth = 20, min_samples_split = 20, min_samples_leaf = 5, max_features = None
#
# Fin de iteracion 74. max_depth = 20, min_samples_split = 20, min_samples_leaf = 5, max_features = None. AUC train = 0.9829357943707159 -  AUC val = 0.7838994502977553 -  time = 0.06459820000009131
#
# Inicio de iteracion 75. max_depth = 20, min_samples_split = 20, min_samples_leaf = 5, max_features = 1
#
# Fin de iteracion 75. max_depth = 20, min_samples_split = 20, min_samples_leaf = 5, max_features = 1. AUC train = 0.9707772346854509 -  AUC val = 0.840400824553367 -  time = 0.021038899999894056
#
# Inicio de iteracion 76. max_depth = 20, min_samples_split = 20, min_samples_leaf = 5, max_features = 2
#
# Fin de iteracion 76. max_depth = 20, min_samples_split = 20, min_samples_leaf = 5, max_features = 2. AUC train = 0.9680626030491378 -  AUC val = 0.8456533440219881 -  time = 0.02237039999999979
#
# Inicio de iteracion 77. max_depth = 20, min_samples_split = 20, min_samples_leaf = 20, max_features = None
#
# Fin de iteracion 77. max_depth = 20, min_samples_split = 20, min_samples_leaf = 20, max_features = None. AUC train = 0.9686876940173165 -  AUC val = 0.8776431516262024 -  time = 0.05966569999986859
#
# Inicio de iteracion 78. max_depth = 20, min_samples_split = 20, min_samples_leaf = 20, max_features = 1
#
# Fin de iteracion 78. max_depth = 20, min_samples_split = 20, min_samples_leaf = 20, max_features = 1. AUC train = 0.9613005773447072 -  AUC val = 0.8918781493357765 -  time = 0.01917849999995269
#
# Inicio de iteracion 79. max_depth = 20, min_samples_split = 20, min_samples_leaf = 20, max_features = 2
#
# Fin de iteracion 79. max_depth = 20, min_samples_split = 20, min_samples_leaf = 20, max_features = 2. AUC train = 0.9481818557534116 -  AUC val = 0.8763479157123224 -  time = 0.021718299999974988
#
# Inicio de iteracion 80. n_trees = 10, max_depth = 6, min_samples_split = 2, min_samples_leaf = 1, max_features = None
# Fin de iteracion 80. n_trees = 10, max_depth = 6, min_samples_split = 2, min_samples_leaf = 1, max_features = None. AUC train = 0.960129613129503 -  AUC val = 0.9380021759047183 -  time = 0.2478633999999147
#
# Inicio de iteracion 81. n_trees = 10, max_depth = 6, min_samples_split = 2, min_samples_leaf = 1, max_features = 1
#
# Fin de iteracion 81. n_trees = 10, max_depth = 6, min_samples_split = 2, min_samples_leaf = 1, max_features = 1. AUC train = 0.9403565772913136 -  AUC val = 0.9282363719651856 -  time = 0.06143549999978859
#
# Inicio de iteracion 82. n_trees = 10, max_depth = 6, min_samples_split = 2, min_samples_leaf = 1, max_features = 2
#
# Fin de iteracion 82. n_trees = 10, max_depth = 6, min_samples_split = 2, min_samples_leaf = 1, max_features = 2. AUC train = 0.9451931965171927 -  AUC val = 0.9331504809894642 -  time = 0.06629640000005566
#
# Inicio de iteracion 83. n_trees = 10, max_depth = 6, min_samples_split = 2, min_samples_leaf = 5, max_features = None
#
# Fin de iteracion 83. n_trees = 10, max_depth = 6, min_samples_split = 2, min_samples_leaf = 5, max_features = None. AUC train = 0.9583801233855794 -  AUC val = 0.9385747824095283 -  time = 0.22621330000015405
#
# Inicio de iteracion 84. n_trees = 10, max_depth = 6, min_samples_split = 2, min_samples_leaf = 5, max_features = 1
#
# Fin de iteracion 84. n_trees = 10, max_depth = 6, min_samples_split = 2, min_samples_leaf = 5, max_features = 1. AUC train = 0.9443653379601 -  AUC val = 0.9325864635822262 -  time = 0.057437299999946845
#
# Inicio de iteracion 85. n_trees = 10, max_depth = 6, min_samples_split = 2, min_samples_leaf = 5, max_features = 2
#
# Fin de iteracion 85. n_trees = 10, max_depth = 6, min_samples_split = 2, min_samples_leaf = 5, max_features = 2. AUC train = 0.9442657382329211 -  AUC val = 0.932723316536876 -  time = 0.0654109999998127
#
# Inicio de iteracion 86. n_trees = 10, max_depth = 6, min_samples_split = 2, min_samples_leaf = 20, max_features = None
#
# Fin de iteracion 86. n_trees = 10, max_depth = 6, min_samples_split = 2, min_samples_leaf = 20, max_features = None. AUC train = 0.9565642252668592 -  AUC val = 0.9393105817682088 -  time = 0.23872179999989385
#
# Inicio de iteracion 87. n_trees = 10, max_depth = 6, min_samples_split = 2, min_samples_leaf = 20, max_features = 1
#
# Fin de iteracion 87. n_trees = 10, max_depth = 6, min_samples_split = 2, min_samples_leaf = 20, max_features = 1. AUC train = 0.9266079901057426 -  AUC val = 0.9166279202931745 -  time = 0.06016240000008111
#
# Inicio de iteracion 88. n_trees = 10, max_depth = 6, min_samples_split = 2, min_samples_leaf = 20, max_features = 2
#
# Fin de iteracion 88. n_trees = 10, max_depth = 6, min_samples_split = 2, min_samples_leaf = 20, max_features = 2. AUC train = 0.9440077030634362 -  AUC val = 0.9347514887769126 -  time = 0.06671269999992546
#
# Inicio de iteracion 89. n_trees = 10, max_depth = 6, min_samples_split = 5, min_samples_leaf = 1, max_features = None
#
# Fin de iteracion 89. n_trees = 10, max_depth = 6, min_samples_split = 5, min_samples_leaf = 1, max_features = None. AUC train = 0.9598034753630578 -  AUC val = 0.9377353412734769 -  time = 0.2298335999998926
#
# Inicio de iteracion 90. n_trees = 10, max_depth = 6, min_samples_split = 5, min_samples_leaf = 1, max_features = 1
#
# Fin de iteracion 90. n_trees = 10, max_depth = 6, min_samples_split = 5, min_samples_leaf = 1, max_features = 1. AUC train = 0.9429880123513931 -  AUC val = 0.932319628950985 -  time = 0.058155200000101104
#
# Inicio de iteracion 91. n_trees = 10, max_depth = 6, min_samples_split = 5, min_samples_leaf = 1, max_features = 2
#
# Fin de iteracion 91. n_trees = 10, max_depth = 6, min_samples_split = 5, min_samples_leaf = 1, max_features = 2. AUC train = 0.9432580610962181 -  AUC val = 0.9299387311039853 -  time = 0.06335300000000643
#
# Inicio de iteracion 92. n_trees = 10, max_depth = 6, min_samples_split = 5, min_samples_leaf = 5, max_features = None
#
# Fin de iteracion 92. n_trees = 10, max_depth = 6, min_samples_split = 5, min_samples_leaf = 5, max_features = None. AUC train = 0.9583801233855794 -  AUC val = 0.9385747824095283 -  time = 0.2209952999999132
#
# Inicio de iteracion 93. n_trees = 10, max_depth = 6, min_samples_split = 5, min_samples_leaf = 5, max_features = 1
#
# Fin de iteracion 93. n_trees = 10, max_depth = 6, min_samples_split = 5, min_samples_leaf = 5, max_features = 1. AUC train = 0.9443653379601 -  AUC val = 0.9325864635822262 -  time = 0.05570910000005824
#
# Inicio de iteracion 94. n_trees = 10, max_depth = 6, min_samples_split = 5, min_samples_leaf = 5, max_features = 2
#
# Fin de iteracion 94. n_trees = 10, max_depth = 6, min_samples_split = 5, min_samples_leaf = 5, max_features = 2. AUC train = 0.9442657382329211 -  AUC val = 0.932723316536876 -  time = 0.0642777999998998
#
# Inicio de iteracion 95. n_trees = 10, max_depth = 6, min_samples_split = 5, min_samples_leaf = 20, max_features = None
#
# Fin de iteracion 95. n_trees = 10, max_depth = 6, min_samples_split = 5, min_samples_leaf = 20, max_features = None. AUC train = 0.9565642252668592 -  AUC val = 0.9393105817682088 -  time = 0.21459619999995994
#
# Inicio de iteracion 96. n_trees = 10, max_depth = 6, min_samples_split = 5, min_samples_leaf = 20, max_features = 1
#
# Fin de iteracion 96. n_trees = 10, max_depth = 6, min_samples_split = 5, min_samples_leaf = 20, max_features = 1. AUC train = 0.9266079901057426 -  AUC val = 0.9166279202931745 -  time = 0.054170399999975416
#
# Inicio de iteracion 97. n_trees = 10, max_depth = 6, min_samples_split = 5, min_samples_leaf = 20, max_features = 2
#
# Fin de iteracion 97. n_trees = 10, max_depth = 6, min_samples_split = 5, min_samples_leaf = 20, max_features = 2. AUC train = 0.9440077030634362 -  AUC val = 0.9347514887769126 -  time = 0.06097920000001977
#
# Inicio de iteracion 98. n_trees = 10, max_depth = 6, min_samples_split = 20, min_samples_leaf = 1, max_features = None
#
# Fin de iteracion 98. n_trees = 10, max_depth = 6, min_samples_split = 20, min_samples_leaf = 1, max_features = None. AUC train = 0.9588500903456804 -  AUC val = 0.9378475721484197 -  time = 0.2226608999999371
#
# Inicio de iteracion 99. n_trees = 10, max_depth = 6, min_samples_split = 20, min_samples_leaf = 1, max_features = 1
#
# Fin de iteracion 99. n_trees = 10, max_depth = 6, min_samples_split = 20, min_samples_leaf = 1, max_features = 1. AUC train = 0.9321477371994457 -  AUC val = 0.920267979844251 -  time = 0.05738540000015746
#
# Inicio de iteracion 100. n_trees = 10, max_depth = 6, min_samples_split = 20, min_samples_leaf = 1, max_features = 2
#
# Fin de iteracion 100. n_trees = 10, max_depth = 6, min_samples_split = 20, min_samples_leaf = 1, max_features = 2. AUC train = 0.943395832162138 -  AUC val = 0.934093563902886 -  time = 0.063727100000051
#
# Inicio de iteracion 101. n_trees = 10, max_depth = 6, min_samples_split = 20, min_samples_leaf = 5, max_features = None
#
# Fin de iteracion 101. n_trees = 10, max_depth = 6, min_samples_split = 20, min_samples_leaf = 5, max_features = None. AUC train = 0.9575527268890771 -  AUC val = 0.9384167430142006 -  time = 0.22705019999989418
#
# Inicio de iteracion 102. n_trees = 10, max_depth = 6, min_samples_split = 20, min_samples_leaf = 5, max_features = 1
#
# Fin de iteracion 102. n_trees = 10, max_depth = 6, min_samples_split = 20, min_samples_leaf = 5, max_features = 1. AUC train = 0.9338961231319596 -  AUC val = 0.9233005038937242 -  time = 0.060023200000159704
#
# Inicio de iteracion 103. n_trees = 10, max_depth = 6, min_samples_split = 20, min_samples_leaf = 5, max_features = 2
#
# Fin de iteracion 103. n_trees = 10, max_depth = 6, min_samples_split = 20, min_samples_leaf = 5, max_features = 2. AUC train = 0.9426832577222519 -  AUC val = 0.9336108566193312 -  time = 0.06690279999997983
#
# Inicio de iteracion 104. n_trees = 10, max_depth = 6, min_samples_split = 20, min_samples_leaf = 20, max_features = None
#
# Fin de iteracion 104. n_trees = 10, max_depth = 6, min_samples_split = 20, min_samples_leaf = 20, max_features = None. AUC train = 0.9565642252668592 -  AUC val = 0.9393105817682088 -  time = 0.22753850000003695
#
# Inicio de iteracion 105. n_trees = 10, max_depth = 6, min_samples_split = 20, min_samples_leaf = 20, max_features = 1
#
# Fin de iteracion 105. n_trees = 10, max_depth = 6, min_samples_split = 20, min_samples_leaf = 20, max_features = 1. AUC train = 0.9266079901057426 -  AUC val = 0.9166279202931745 -  time = 0.05953530000010687
#
# Inicio de iteracion 106. n_trees = 10, max_depth = 6, min_samples_split = 20, min_samples_leaf = 20, max_features = 2
#
# Fin de iteracion 106. n_trees = 10, max_depth = 6, min_samples_split = 20, min_samples_leaf = 20, max_features = 2. AUC train = 0.9440077030634362 -  AUC val = 0.9347514887769126 -  time = 0.06892240000001948
#
# Inicio de iteracion 107. n_trees = 10, max_depth = 20, min_samples_split = 2, min_samples_leaf = 1, max_features = None
# Fin de iteracion 107. n_trees = 10, max_depth = 20, min_samples_split = 2, min_samples_leaf = 1, max_features = None. AUC train = 0.9996885454923038 -  AUC val = 0.8623270728355474 -  time = 0.31132929999989756
#
# Inicio de iteracion 108. n_trees = 10, max_depth = 20, min_samples_split = 2, min_samples_leaf = 1, max_features = 1
#
# Fin de iteracion 108. n_trees = 10, max_depth = 20, min_samples_split = 2, min_samples_leaf = 1, max_features = 1. AUC train = 0.998456563609186 -  AUC val = 0.9005216445258817 -  time = 0.098991500000011
#
# Inicio de iteracion 109. n_trees = 10, max_depth = 20, min_samples_split = 2, min_samples_leaf = 1, max_features = 2
#
# Fin de iteracion 109. n_trees = 10, max_depth = 20, min_samples_split = 2, min_samples_leaf = 1, max_features = 2. AUC train = 0.9992387038379009 -  AUC val = 0.88918689876317 -  time = 0.10142700000005789
#
# Inicio de iteracion 110. n_trees = 10, max_depth = 20, min_samples_split = 2, min_samples_leaf = 5, max_features = None
#
# Fin de iteracion 110. n_trees = 10, max_depth = 20, min_samples_split = 2, min_samples_leaf = 5, max_features = None. AUC train = 0.9882910766088757 -  AUC val = 0.9204930142006413 -  time = 0.29689379999990706
#
# Inicio de iteracion 111. n_trees = 10, max_depth = 20, min_samples_split = 2, min_samples_leaf = 5, max_features = 1
#
# Fin de iteracion 111. n_trees = 10, max_depth = 20, min_samples_split = 2, min_samples_leaf = 5, max_features = 1. AUC train = 0.9793227629272359 -  AUC val = 0.9328200870361888 -  time = 0.08659719999991466
#
# Inicio de iteracion 112. n_trees = 10, max_depth = 20, min_samples_split = 2, min_samples_leaf = 5, max_features = 2
#
# Fin de iteracion 112. n_trees = 10, max_depth = 20, min_samples_split = 2, min_samples_leaf = 5, max_features = 2. AUC train = 0.9792528120879157 -  AUC val = 0.9390557718735685 -  time = 0.09082709999984218
#
# Inicio de iteracion 113. n_trees = 10, max_depth = 20, min_samples_split = 2, min_samples_leaf = 20, max_features = None
#
# Fin de iteracion 113. n_trees = 10, max_depth = 20, min_samples_split = 2, min_samples_leaf = 20, max_features = None. AUC train = 0.9685132918146223 -  AUC val = 0.9338267292716446 -  time = 0.2698164999999335
#
# Inicio de iteracion 114. n_trees = 10, max_depth = 20, min_samples_split = 2, min_samples_leaf = 20, max_features = 1
#
# Fin de iteracion 114. n_trees = 10, max_depth = 20, min_samples_split = 2, min_samples_leaf = 20, max_features = 1. AUC train = 0.9556479847869118 -  AUC val = 0.9392779431974347 -  time = 0.07251820000010412
#
# Inicio de iteracion 115. n_trees = 10, max_depth = 20, min_samples_split = 2, min_samples_leaf = 20, max_features = 2
#
# Fin de iteracion 115. n_trees = 10, max_depth = 20, min_samples_split = 2, min_samples_leaf = 20, max_features = 2. AUC train = 0.9506893815652713 -  AUC val = 0.9353956710948237 -  time = 0.07368559999986246
#
# Inicio de iteracion 116. n_trees = 10, max_depth = 20, min_samples_split = 5, min_samples_leaf = 1, max_features = None
#
# Fin de iteracion 116. n_trees = 10, max_depth = 20, min_samples_split = 5, min_samples_leaf = 1, max_features = None. AUC train = 0.9985196862197873 -  AUC val = 0.8893443655519927 -  time = 0.30876199999988785
#
# Inicio de iteracion 117. n_trees = 10, max_depth = 20, min_samples_split = 5, min_samples_leaf = 1, max_features = 1
#
# Fin de iteracion 117. n_trees = 10, max_depth = 20, min_samples_split = 5, min_samples_leaf = 1, max_features = 1. AUC train = 0.9947674718585848 -  AUC val = 0.9207197663765461 -  time = 0.09502849999989849
#
# Inicio de iteracion 118. n_trees = 10, max_depth = 20, min_samples_split = 5, min_samples_leaf = 1, max_features = 2
#
# Fin de iteracion 118. n_trees = 10, max_depth = 20, min_samples_split = 5, min_samples_leaf = 1, max_features = 2. AUC train = 0.9955136227013447 -  AUC val = 0.9095590929912963 -  time = 0.09757379999996374
#
# Inicio de iteracion 119. n_trees = 10, max_depth = 20, min_samples_split = 5, min_samples_leaf = 5, max_features = None
#
# Fin de iteracion 119. n_trees = 10, max_depth = 20, min_samples_split = 5, min_samples_leaf = 5, max_features = None. AUC train = 0.9882910766088757 -  AUC val = 0.9204930142006413 -  time = 0.2975786999998036
#
# Inicio de iteracion 120. n_trees = 10, max_depth = 20, min_samples_split = 5, min_samples_leaf = 5, max_features = 1
#
# Fin de iteracion 120. n_trees = 10, max_depth = 20, min_samples_split = 5, min_samples_leaf = 5, max_features = 1. AUC train = 0.9793227629272359 -  AUC val = 0.9328200870361888 -  time = 0.08678039999995235
#
# Inicio de iteracion 121. n_trees = 10, max_depth = 20, min_samples_split = 5, min_samples_leaf = 5, max_features = 2
#
# Fin de iteracion 121. n_trees = 10, max_depth = 20, min_samples_split = 5, min_samples_leaf = 5, max_features = 2. AUC train = 0.9792528120879157 -  AUC val = 0.9390557718735685 -  time = 0.0877775000001293
#
# Inicio de iteracion 122. n_trees = 10, max_depth = 20, min_samples_split = 5, min_samples_leaf = 20, max_features = None
#
# Fin de iteracion 122. n_trees = 10, max_depth = 20, min_samples_split = 5, min_samples_leaf = 20, max_features = None. AUC train = 0.9685132918146223 -  AUC val = 0.9338267292716446 -  time = 0.27091249999989486
#
# Inicio de iteracion 123. n_trees = 10, max_depth = 20, min_samples_split = 5, min_samples_leaf = 20, max_features = 1
#
# Fin de iteracion 123. n_trees = 10, max_depth = 20, min_samples_split = 5, min_samples_leaf = 20, max_features = 1. AUC train = 0.9556479847869118 -  AUC val = 0.9392779431974347 -  time = 0.07286040000008143
#
# Inicio de iteracion 124. n_trees = 10, max_depth = 20, min_samples_split = 5, min_samples_leaf = 20, max_features = 2
#
# Fin de iteracion 124. n_trees = 10, max_depth = 20, min_samples_split = 5, min_samples_leaf = 20, max_features = 2. AUC train = 0.9506893815652713 -  AUC val = 0.9353956710948237 -  time = 0.07394989999988866
#
# Inicio de iteracion 125. n_trees = 10, max_depth = 20, min_samples_split = 20, min_samples_leaf = 1, max_features = None
#
# Fin de iteracion 125. n_trees = 10, max_depth = 20, min_samples_split = 20, min_samples_leaf = 1, max_features = None. AUC train = 0.9884094154599826 -  AUC val = 0.9178618873110398 -  time = 0.2979382999999416
#
# Inicio de iteracion 126. n_trees = 10, max_depth = 20, min_samples_split = 20, min_samples_leaf = 1, max_features = 1
#
# Fin de iteracion 126. n_trees = 10, max_depth = 20, min_samples_split = 20, min_samples_leaf = 1, max_features = 1. AUC train = 0.9833977522805898 -  AUC val = 0.9326672010994047 -  time = 0.09373890000006213
#
# Inicio de iteracion 127. n_trees = 10, max_depth = 20, min_samples_split = 20, min_samples_leaf = 1, max_features = 2
#
# Fin de iteracion 127. n_trees = 10, max_depth = 20, min_samples_split = 20, min_samples_leaf = 1, max_features = 2. AUC train = 0.9828758291741463 -  AUC val = 0.9297869903802106 -  time = 0.0939846999999645
#
# Inicio de iteracion 128. n_trees = 10, max_depth = 20, min_samples_split = 20, min_samples_leaf = 5, max_features = None
#
# Fin de iteracion 128. n_trees = 10, max_depth = 20, min_samples_split = 20, min_samples_leaf = 5, max_features = None. AUC train = 0.9821775272724846 -  AUC val = 0.9285284012826387 -  time = 0.28916239999989557
#
# Inicio de iteracion 129. n_trees = 10, max_depth = 20, min_samples_split = 20, min_samples_leaf = 5, max_features = 1
#
# Fin de iteracion 129. n_trees = 10, max_depth = 20, min_samples_split = 20, min_samples_leaf = 5, max_features = 1. AUC train = 0.9734030993484176 -  AUC val = 0.9384213238662391 -  time = 0.08526469999992514
#
# Inicio de iteracion 130. n_trees = 10, max_depth = 20, min_samples_split = 20, min_samples_leaf = 5, max_features = 2
#
# Fin de iteracion 130. n_trees = 10, max_depth = 20, min_samples_split = 20, min_samples_leaf = 5, max_features = 2. AUC train = 0.9727328547925822 -  AUC val = 0.9344766376546038 -  time = 0.08651299999996809
#
# Inicio de iteracion 131. n_trees = 10, max_depth = 20, min_samples_split = 20, min_samples_leaf = 20, max_features = None
#
# Fin de iteracion 131. n_trees = 10, max_depth = 20, min_samples_split = 20, min_samples_leaf = 20, max_features = None. AUC train = 0.9685132918146223 -  AUC val = 0.9338267292716446 -  time = 0.2688445999999658
#
# Inicio de iteracion 132. n_trees = 10, max_depth = 20, min_samples_split = 20, min_samples_leaf = 20, max_features = 1
#
# Fin de iteracion 132. n_trees = 10, max_depth = 20, min_samples_split = 20, min_samples_leaf = 20, max_features = 1. AUC train = 0.9556479847869118 -  AUC val = 0.9392779431974347 -  time = 0.07412550000003648
#
# Inicio de iteracion 133. n_trees = 10, max_depth = 20, min_samples_split = 20, min_samples_leaf = 20, max_features = 2
#
# Fin de iteracion 133. n_trees = 10, max_depth = 20, min_samples_split = 20, min_samples_leaf = 20, max_features = 2. AUC train = 0.9506893815652713 -  AUC val = 0.9353956710948237 -  time = 0.07575180000003456
#
# Inicio de iteracion 134. n_trees = 100, max_depth = 6, min_samples_split = 2, min_samples_leaf = 1, max_features = None
# Fin de iteracion 134. n_trees = 100, max_depth = 6, min_samples_split = 2, min_samples_leaf = 1, max_features = None. AUC train = 0.9632857949996317 -  AUC val = 0.942415254237288 -  time = 2.2102101000000403
#
# Inicio de iteracion 135. n_trees = 100, max_depth = 6, min_samples_split = 2, min_samples_leaf = 1, max_features = 1
#
# Fin de iteracion 135. n_trees = 100, max_depth = 6, min_samples_split = 2, min_samples_leaf = 1, max_features = 1. AUC train = 0.9501037454374724 -  AUC val = 0.9343329134218965 -  time = 0.5596038000001045
#
# Inicio de iteracion 136. n_trees = 100, max_depth = 6, min_samples_split = 2, min_samples_leaf = 1, max_features = 2
#
# Fin de iteracion 136. n_trees = 100, max_depth = 6, min_samples_split = 2, min_samples_leaf = 1, max_features = 2. AUC train = 0.9513822670900168 -  AUC val = 0.9359631241410903 -  time = 0.5749939999998332
#
# Inicio de iteracion 137. n_trees = 100, max_depth = 6, min_samples_split = 2, min_samples_leaf = 5, max_features = None
#
# Fin de iteracion 137. n_trees = 100, max_depth = 6, min_samples_split = 2, min_samples_leaf = 5, max_features = None. AUC train = 0.9612133762433601 -  AUC val = 0.9422010994044893 -  time = 2.2329416000000037
#
# Inicio de iteracion 138. n_trees = 100, max_depth = 6, min_samples_split = 2, min_samples_leaf = 5, max_features = 1
#
# Fin de iteracion 138. n_trees = 100, max_depth = 6, min_samples_split = 2, min_samples_leaf = 5, max_features = 1. AUC train = 0.9466737156576677 -  AUC val = 0.9336669720568025 -  time = 0.49675490000004174
#
# Inicio de iteracion 139. n_trees = 100, max_depth = 6, min_samples_split = 2, min_samples_leaf = 5, max_features = 2
#
# Fin de iteracion 139. n_trees = 100, max_depth = 6, min_samples_split = 2, min_samples_leaf = 5, max_features = 2. AUC train = 0.9487006214458235 -  AUC val = 0.9351213925790197 -  time = 0.5544698999999582
#
# Inicio de iteracion 140. n_trees = 100, max_depth = 6, min_samples_split = 2, min_samples_leaf = 20, max_features = None
#
# Fin de iteracion 140. n_trees = 100, max_depth = 6, min_samples_split = 2, min_samples_leaf = 20, max_features = None. AUC train = 0.9581301486063867 -  AUC val = 0.9428011910215299 -  time = 2.228670799999918
#
# Inicio de iteracion 141. n_trees = 100, max_depth = 6, min_samples_split = 2, min_samples_leaf = 20, max_features = 1
#
# Fin de iteracion 141. n_trees = 100, max_depth = 6, min_samples_split = 2, min_samples_leaf = 20, max_features = 1. AUC train = 0.9441802570237702 -  AUC val = 0.9318947549244159 -  time = 0.48008759999993345
#
# Inicio de iteracion 142. n_trees = 100, max_depth = 6, min_samples_split = 2, min_samples_leaf = 20, max_features = 2
#
# Fin de iteracion 142. n_trees = 100, max_depth = 6, min_samples_split = 2, min_samples_leaf = 20, max_features = 2. AUC train = 0.946924075487352 -  AUC val = 0.9357844709115896 -  time = 0.5348716000000877
#
# Inicio de iteracion 143. n_trees = 100, max_depth = 6, min_samples_split = 5, min_samples_leaf = 1, max_features = None
#
# Fin de iteracion 143. n_trees = 100, max_depth = 6, min_samples_split = 5, min_samples_leaf = 1, max_features = None. AUC train = 0.9630099448273985 -  AUC val = 0.9423602840128262 -  time = 2.233372600000166
#
# Inicio de iteracion 144. n_trees = 100, max_depth = 6, min_samples_split = 5, min_samples_leaf = 1, max_features = 1
#
# Fin de iteracion 144. n_trees = 100, max_depth = 6, min_samples_split = 5, min_samples_leaf = 1, max_features = 1. AUC train = 0.9495409299688136 -  AUC val = 0.9353618873110399 -  time = 0.5132908999999017
#
# Inicio de iteracion 145. n_trees = 100, max_depth = 6, min_samples_split = 5, min_samples_leaf = 1, max_features = 2
#
# Fin de iteracion 145. n_trees = 100, max_depth = 6, min_samples_split = 5, min_samples_leaf = 1, max_features = 2. AUC train = 0.9503220947362828 -  AUC val = 0.9350624141090242 -  time = 0.6301902000000155
#
# Inicio de iteracion 146. n_trees = 100, max_depth = 6, min_samples_split = 5, min_samples_leaf = 5, max_features = None
#
# Fin de iteracion 146. n_trees = 100, max_depth = 6, min_samples_split = 5, min_samples_leaf = 5, max_features = None. AUC train = 0.9612133762433601 -  AUC val = 0.9422010994044893 -  time = 2.439141800000016
#
# Inicio de iteracion 147. n_trees = 100, max_depth = 6, min_samples_split = 5, min_samples_leaf = 5, max_features = 1
#
# Fin de iteracion 147. n_trees = 100, max_depth = 6, min_samples_split = 5, min_samples_leaf = 5, max_features = 1. AUC train = 0.9466737156576677 -  AUC val = 0.9336669720568025 -  time = 0.5084904000000279
#
# Inicio de iteracion 148. n_trees = 100, max_depth = 6, min_samples_split = 5, min_samples_leaf = 5, max_features = 2
#
# Fin de iteracion 148. n_trees = 100, max_depth = 6, min_samples_split = 5, min_samples_leaf = 5, max_features = 2. AUC train = 0.9487006214458235 -  AUC val = 0.9351213925790197 -  time = 0.587855799999943
#
# Inicio de iteracion 149. n_trees = 100, max_depth = 6, min_samples_split = 5, min_samples_leaf = 20, max_features = None
#
# Fin de iteracion 149. n_trees = 100, max_depth = 6, min_samples_split = 5, min_samples_leaf = 20, max_features = None. AUC train = 0.9581301486063867 -  AUC val = 0.9428011910215299 -  time = 2.2708141000000523
#
# Inicio de iteracion 150. n_trees = 100, max_depth = 6, min_samples_split = 5, min_samples_leaf = 20, max_features = 1
#
# Fin de iteracion 150. n_trees = 100, max_depth = 6, min_samples_split = 5, min_samples_leaf = 20, max_features = 1. AUC train = 0.9441802570237702 -  AUC val = 0.9318947549244159 -  time = 0.5644457999999304
#
# Inicio de iteracion 151. n_trees = 100, max_depth = 6, min_samples_split = 5, min_samples_leaf = 20, max_features = 2
#
# Fin de iteracion 151. n_trees = 100, max_depth = 6, min_samples_split = 5, min_samples_leaf = 20, max_features = 2. AUC train = 0.946924075487352 -  AUC val = 0.9357844709115896 -  time = 0.6253014000001258
#
# Inicio de iteracion 152. n_trees = 100, max_depth = 6, min_samples_split = 20, min_samples_leaf = 1, max_features = None
#
# Fin de iteracion 152. n_trees = 100, max_depth = 6, min_samples_split = 20, min_samples_leaf = 1, max_features = None. AUC train = 0.9614213291788951 -  AUC val = 0.9424049473202015 -  time = 2.457212100000106
#
# Inicio de iteracion 153. n_trees = 100, max_depth = 6, min_samples_split = 20, min_samples_leaf = 1, max_features = 1
#
# Fin de iteracion 153. n_trees = 100, max_depth = 6, min_samples_split = 20, min_samples_leaf = 1, max_features = 1. AUC train = 0.9485841051670438 -  AUC val = 0.9337660329821347 -  time = 0.5435947000000851
#
# Inicio de iteracion 154. n_trees = 100, max_depth = 6, min_samples_split = 20, min_samples_leaf = 1, max_features = 2
#
# Fin de iteracion 154. n_trees = 100, max_depth = 6, min_samples_split = 20, min_samples_leaf = 1, max_features = 2. AUC train = 0.9491910474220485 -  AUC val = 0.9351683463124141 -  time = 0.6159712000001036
#
# Inicio de iteracion 155. n_trees = 100, max_depth = 6, min_samples_split = 20, min_samples_leaf = 5, max_features = None
#
# ...
# C:\Users\jesus\anaconda3\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# Fin de iteracion 1254. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 0.1, parametro num_parallel_tree = 20, parametro lambda = 0, parametro alpha = 0. AUC train = 0.9878883137945879 -  AUC val = 0.9327880210719194 -  time = 7.605463200000486
#
# Inicio de iteracion 1255. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 0.1, parametro num_parallel_tree = 20, parametro lambda = 0, parametro alpha = 1
#
# [14:03:10] WARNING: ..\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# C:\Users\jesus\anaconda3\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# Fin de iteracion 1255. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 0.1, parametro num_parallel_tree = 20, parametro lambda = 0, parametro alpha = 1. AUC train = 0.9876250932784817 -  AUC val = 0.9335037792029317 -  time = 7.043005200000152
#
# Inicio de iteracion 1256. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 0.1, parametro num_parallel_tree = 20, parametro lambda = 1, parametro alpha = 0
#
# [14:03:17] WARNING: ..\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# C:\Users\jesus\anaconda3\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# Fin de iteracion 1256. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 0.1, parametro num_parallel_tree = 20, parametro lambda = 1, parametro alpha = 0. AUC train = 0.987896168824618 -  AUC val = 0.9333984196060467 -  time = 7.229979900000217
#
# Inicio de iteracion 1257. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 0.1, parametro num_parallel_tree = 20, parametro lambda = 1, parametro alpha = 1
#
# [14:03:24] WARNING: ..\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# C:\Users\jesus\anaconda3\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# Fin de iteracion 1257. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 0.1, parametro num_parallel_tree = 20, parametro lambda = 1, parametro alpha = 1. AUC train = 0.9870138127879376 -  AUC val = 0.9340683692166745 -  time = 7.0045178000000305
#
# Inicio de iteracion 1258. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 1, parametro num_parallel_tree = 1, parametro lambda = 0, parametro alpha = 0
#
# [14:03:31] WARNING: ..\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# C:\Users\jesus\anaconda3\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# Fin de iteracion 1258. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 1, parametro num_parallel_tree = 1, parametro lambda = 0, parametro alpha = 0. AUC train = 0.9996563296011672 -  AUC val = 0.9250314933577646 -  time = 2.1334907000000385
#
# Inicio de iteracion 1259. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 1, parametro num_parallel_tree = 1, parametro lambda = 0, parametro alpha = 1
#
# [14:03:33] WARNING: ..\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# C:\Users\jesus\anaconda3\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# Fin de iteracion 1259. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 1, parametro num_parallel_tree = 1, parametro lambda = 0, parametro alpha = 1. AUC train = 0.9995447162986482 -  AUC val = 0.9227582455336693 -  time = 2.0497058999999354
#
# Inicio de iteracion 1260. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 1, parametro num_parallel_tree = 1, parametro lambda = 1, parametro alpha = 0
#
# [14:03:35] WARNING: ..\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# C:\Users\jesus\anaconda3\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# Fin de iteracion 1260. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 1, parametro num_parallel_tree = 1, parametro lambda = 1, parametro alpha = 0. AUC train = 0.9997076183266579 -  AUC val = 0.9199604901511682 -  time = 2.1527162000002136
#
# Inicio de iteracion 1261. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 1, parametro num_parallel_tree = 1, parametro lambda = 1, parametro alpha = 1
#
# [14:03:37] WARNING: ..\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# C:\Users\jesus\anaconda3\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# Fin de iteracion 1261. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 1, parametro num_parallel_tree = 1, parametro lambda = 1, parametro alpha = 1. AUC train = 0.9995042346569573 -  AUC val = 0.921747022446175 -  time = 2.4042325000000346
#
# Inicio de iteracion 1262. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 1, parametro num_parallel_tree = 20, parametro lambda = 0, parametro alpha = 0
# C:\Users\jesus\anaconda3\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [14:03:40] WARNING: ..\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Fin de iteracion 1262. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 1, parametro num_parallel_tree = 20, parametro lambda = 0, parametro alpha = 0. AUC train = 0.9996563296011672 -  AUC val = 0.9250314933577646 -  time = 44.831238399999165
#
# Inicio de iteracion 1263. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 1, parametro num_parallel_tree = 20, parametro lambda = 0, parametro alpha = 1
# C:\Users\jesus\anaconda3\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [14:04:25] WARNING: ..\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Fin de iteracion 1263. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 1, parametro num_parallel_tree = 20, parametro lambda = 0, parametro alpha = 1. AUC train = 0.9995288522183914 -  AUC val = 0.9214034585432891 -  time = 50.067550499999925
#
# Inicio de iteracion 1264. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 1, parametro num_parallel_tree = 20, parametro lambda = 1, parametro alpha = 0
# C:\Users\jesus\anaconda3\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [14:05:15] WARNING: ..\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Fin de iteracion 1264. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 1, parametro num_parallel_tree = 20, parametro lambda = 1, parametro alpha = 0. AUC train = 0.9997076183266578 -  AUC val = 0.9199604901511681 -  time = 39.91525790000014
#
# Inicio de iteracion 1265. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 1, parametro num_parallel_tree = 20, parametro lambda = 1, parametro alpha = 1
# C:\Users\jesus\anaconda3\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [14:05:55] WARNING: ..\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Fin de iteracion 1265. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 1, parametro num_parallel_tree = 20, parametro lambda = 1, parametro alpha = 1. AUC train = 0.99950426032699 -  AUC val = 0.921747022446175 -  time = 39.57436830000006

# %%
grid_results.groupby(['model'], sort=False)['time'].mean().sort_values()
# Out:
# model
# decision tree           0.028966
# Logistic Regression     1.483847
# xgboost                 4.739003
# random forest           5.902209
# SVM                    12.810233
# Name: time, dtype: float64

# %% [markdown]
# Veamos los resultados.

# %%
grid_results
# Out:
#                     model                                             params  \
# 0     Logistic Regression         {'regularization': ['l1'], 'penalty': [1]}
# 1     Logistic Regression        {'regularization': ['l1'], 'penalty': [10]}
# 2     Logistic Regression       {'regularization': ['l1'], 'penalty': [100]}
# 3     Logistic Regression         {'regularization': ['l2'], 'penalty': [1]}
# 4     Logistic Regression        {'regularization': ['l2'], 'penalty': [10]}
# ...                   ...                                                ...
# 1260              xgboost  {'nrounds': [100], 'eta': [0.99], 'gamma': [1]...
# 1261              xgboost  {'nrounds': [100], 'eta': [0.99], 'gamma': [1]...
# 1262              xgboost  {'nrounds': [100], 'eta': [0.99], 'gamma': [1]...
# 1263              xgboost  {'nrounds': [100], 'eta': [0.99], 'gamma': [1]...
# 1264              xgboost  {'nrounds': [100], 'eta': [0.99], 'gamma': [1]...
#
#       auc_train   auc_val       time
# 0      0.940572  0.938050   0.987557
# 1      0.940520  0.937836   9.117579
# 2      0.940513  0.937672   2.224766
# 3      0.940531  0.938426   0.161936
# 4      0.940515  0.938951   0.166269
# ...         ...       ...        ...
# 1260   0.999504  0.921747   2.404233
# 1261   0.999656  0.925031  44.831238
# 1262   0.999529  0.921403  50.067550
# 1263   0.999708  0.919960  39.915258
# 1264   0.999504  0.921747  39.574368
#
# [1265 rows x 5 columns]

# %% [markdown]
# Vamos a analizar el mejor resultado para cada familia de modelos.

# %%
grid_results.groupby(['model'], sort=False)['auc_val'].max().sort_values()
# Out:
# model
# decision tree          0.937351
# Logistic Regression    0.938951
# SVM                    0.939226
# random forest          0.943185
# xgboost                0.945624
# Name: auc_val, dtype: float64

# %% [markdown]
# Nos quedamos con la mejor combinación de familia de modelos + hiperparámetros.

# %%
best_params = grid_results.iloc[grid_results['auc_val'].idxmax()]

# %% [markdown]
# Juntamos validación y train para entrenar el modelo final.

# %%
print('Train data size = ' + str(X_train.shape))
print('Train target size = ' + str(y_train.shape))
print('Validation data size = ' + str(X_val.shape))
print('Validation target size = ' + str(y_val.shape))

# Combinar train y validación
X_train = pd.concat((X_train,X_val), axis = 0)
y_train = np.concatenate((y_train, y_val), axis = 0)

del X_val, y_val

print('Train data size = ' + str(X_train.shape))
print('Train target size = ' + str(y_train.shape))
# Out:
# Train data size = (22894, 22)
# Train target size = (22894,)
# Validation data size = (4905, 22)
# Validation target size = (4905,)
# Train data size = (27799, 22)
# Train target size = (27799,)

# %% [markdown]
# Y ahora entrenamos el modelo final.

# %%
# Logistic Regression
if best_params['model'] == 'logistic regression':       

    # Entrenar modelo
    if best_params['params']['regularization'] == 'l1':
        model = LogisticRegression(penalty = best_params['params']['regularization'][0], solver = 'liblinear', C = best_params['params']['penalty'][0], random_state = random_state)
    else:
        model = LogisticRegression(penalty = best_params['params']['regularization'][0],solver = 'lbfgs', C = best_params['params']['penalty'][0], random_state = random_state)


# SVM
elif best_params['model'] == 'SVM':

    model = SVC(C = best_params['params']['C'][0], gamma = best_params['params']['gamma_kernel'][0], probability = True, 
                random_state = random_state)             


# Decision Tree
elif best_params['model'] == 'decision tree':
    model = DecisionTreeClassifier(max_depth = int(best_params['params']['max_depth'][0]),
                                                  min_samples_split = int(best_params['params']['min_samples_split'][0]),
                                                  min_samples_leaf = int(best_params['params']['min_samples_leaf'][0]),
                                                  max_features = int(best_params['params']['max_features'][0]), 
                                   random_state = random_state)


# Random Forest
elif best_params['model'] == 'random forest':
    model = RandomForestClassifier(n_estimators = int(best_params['params']['n_trees'][0]),
                                                      max_depth = int(best_params['params']['max_depth'][0]),
                                                      min_samples_split = int(best_params['params']['min_samples_split'][0]),
                                                      min_samples_leaf = int(best_params['params']['min_samples_leaf'][0]),
                                                      max_features = int(best_params['params']['max_features'][0]), 
                                                      random_state = random_state)

# XGBOOST
elif best_params['model'] == 'xgboost':
    model = XGBClassifier(nthread = nthread, 
                                                              scale_pos_weight = scale_pos_weight,
                                                              random_state = random_state,
                                                              n_estimators = int(best_params['params']['nrounds'][0]), 
                                                              learning_rate = best_params['params']['eta'][0], 
                                                              gamma = best_params['params']['gamma'][0],
                                                              max_depth = int(best_params['params']['max_depth'][0]),
                                                              min_child_weight = best_params['params']['min_child_weight'][0],
                                                              subsample = best_params['params']['subsample'][0],
                                                              colsample_bytree = best_params['params']['colsample_bytree'][0],
                                                              num_parallel_tree  = int(best_params['params']['num_parallel_tree'][0]),
                                                              reg_lambda = best_params['params']['lamda'][0],
                                                              reg_alpha = best_params['params']['alpha'][0])

# Entrenar modelo
model.fit(X_train, np.array(y_train))

# Generar predicciones
pred_train_p = model.predict_proba(X_train)
pred_test_p = model.predict_proba(X_test)

# Calcular métricas de evaluación
auc_train = metric(y_train, pred_train_p[:, 1])
auc_test = metric(y_test, pred_test_p[:, 1]) 

results = pd.DataFrame()
results = results.append(pd.DataFrame(data={'model':best_params['model'],'auc_train':[auc_train],'auc_test':[auc_test]}, columns=['model',  'auc_train', 'auc_test']), ignore_index=True)

# %%
results
# Out:
#      model  auc_train  auc_test
# 0  xgboost   0.961011  0.937501
