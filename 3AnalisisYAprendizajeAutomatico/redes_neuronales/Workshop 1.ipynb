# %% [markdown]
# # Workshop 1: Mobile Price Range Classification
#
# In this workshop we will learn how to train a neural network with numeric data as input to predict the price range of mobile phones ([info of the data](https://www.kaggle.com/iabhishekofficial/mobile-price-classification/data#)). The main blocks of the workshop are:
#
# 1. Get the data from Google Drive.
# 2. Load and Pre-process the data.
# 3. Define a Fully Connected Neural Network.
# 4. Choose loss function and optimizer.
# 5. Train the network.
#
# The main libraries thar will be used in the workshop are:
#
# - Tensorflow
# - Keras
# - Sci-kit Learn
# - Matplotlib
# - Numpy
# - Pandas
#
# [Reference](https://towardsdatascience.com/building-our-first-neural-network-in-keras-bdc8abbc17f5)

# %% [markdown]
# ## 1. Get the data from Google Drive

# %%
'''# Import libraries to interact with Google Drive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials'''

# %%
'''# Authenticate with your Google account to get access to the data
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)'''

# %%
'''# Download data
download = drive.CreateFile({'id': '1igTyUp-YTHG0ig9VeNu83R8jBWn5Djji'})
download.GetContentFile('mobile_price.zip')'''

# %%
'''# Extract data from zip file
import zipfile
from pathlib import Path
data_path = Path("./mobile_price.zip")

with zipfile.ZipFile(str(data_path), 'r') as zip_ref:
    zip_ref.extractall("./data")'''

# %%
'''# List files of ./data directory
# !ls ./data'''
# Out:
# test.csv  train.csv

# %% [markdown]
# ## 2. Load and Pre-process the data

# %%
# Load dependencies for loading data
import numpy as np
import pandas as pd

# %%
# Load training dataset and check variables
dataset = pd.read_csv('./data/train.csv')

# %%
# Show variables
dataset.columns
# Out:
# Index(['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
#        'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
#        'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi', 'price_range'],
#       dtype='object')

# %%
# Show first 5 rows
dataset.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
#    three_g  touch_screen  wifi  price_range
# 0        0             0     1            1
# 1        1             1     0            2
# 2        1             1     0            2
# 3        1             0     0            2
# 4        1             1     0            1
#
# [5 rows x 21 columns]

# %%
# Import dependencies for pre-processing
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split

# %%
# Convert pandas Dataframe to Numpy Array
dataset_numpy = dataset.values

# %%
# Show data type before and after conversion
print(type(dataset))
print(type(dataset_numpy.dtype))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'numpy.dtype[float64]'>

# %%
# Separate input variables from output label
X = dataset_numpy[:, :20]
y = dataset_numpy[:, 20:21]

# %%
# Show shape of training data and labels
print("Shape of training data: ", X.shape)
print("Shape of training labels: ", y.shape)
# Out:
# Shape of training data:  (2000, 20)
# Shape of training labels:  (2000, 1)

# %%
# Show different classes to predict
np.unique(y)
# Out:
# array([0., 1., 2., 3.])

# %%
# Normalizing the data to improve stability while training
sc = StandardScaler()
sc.fit(X)
X_norm = sc.transform(X)

# %%
# Show mean and Standard Deviation learnt from training data
print("Mean per variable: \n", sc.mean_)
print("Standard Deviation per variable: \n", sc.scale_)
# Out:
# Mean per variable:
#  [1.2385185e+03 4.9500000e-01 1.5222500e+00 5.0950000e-01 4.3095000e+00
#  5.2150000e-01 3.2046500e+01 5.0175000e-01 1.4024900e+02 4.5205000e+00
#  9.9165000e+00 6.4510800e+02 1.2515155e+03 2.1242130e+03 1.2306500e+01
#  5.7670000e+00 1.1011000e+01 7.6150000e-01 5.0300000e-01 5.0700000e-01]
# Standard Deviation per variable:
#  [4.39308338e+02 4.99974999e-01 8.15800182e-01 4.99909742e-01
#  4.34035825e+00 4.99537536e-01 1.81411780e+01 2.88343437e-01
#  3.53908039e+01 2.28726469e+00 6.06279867e+00 4.43669852e+02
#  4.32091384e+02 1.08446083e+03 4.21219156e+00 4.35530837e+00
#  5.46258904e+00 4.26166341e-01 4.99991000e-01 4.99950998e-01]

# %%
# Show data before and after normalization
print("Before normalization: \n", X[1, :])
print("After normalization: \n", X_norm[1, :])
# Out:
# Before normalization:
#  [1.021e+03 1.000e+00 5.000e-01 1.000e+00 0.000e+00 1.000e+00 5.300e+01
#  7.000e-01 1.360e+02 3.000e+00 6.000e+00 9.050e+02 1.988e+03 2.631e+03
#  1.700e+01 3.000e+00 7.000e+00 1.000e+00 1.000e+00 0.000e+00]
# After normalization:
#  [-0.49513857  1.0100505  -1.2530642   0.98117712 -0.99289039  0.95788598
#   1.15502422  0.68754816 -0.12005944 -0.66476784 -0.64598879  0.58577791
#   1.70446468  0.46731702  1.11426556 -0.63531667 -0.73426721  0.55964063
#   0.99401789 -1.01409939]

# %%
# One-hot encoding of labels
onehot_enc = OneHotEncoder()
y_onehot = onehot_enc.fit_transform(y).toarray()

# %%
# Show labels before and after one-hot encoding
print("Before onet-hot encodeing: \n", y[0])
print("After onet-hot encodeing: \n", y_onehot[0])
# Out:
# Before onet-hot encodeing:
#  [1.]
# After onet-hot encodeing:
#  [0. 1. 0. 0.]

# %%
# Split data in training and validation partitions
X_train, X_val, y_train, y_val = train_test_split(X_norm, y_onehot, 
                                                  test_size=0.1)

# %%
# Show sizes of partitions
print("Size of training data: ", X_train.shape)
print("Size of training labels: ", y_train.shape)
print("Size of validation data: ", X_val.shape)
print("Size of validation labels: ", y_val.shape)
# Out:
# Size of training data:  (1800, 20)
# Size of training labels:  (1800, 4)
# Size of validation data:  (200, 20)
# Size of validation labels:  (200, 4)

# %% [markdown]
# ## 3. Define a Fully Connected Neural Network

# %%
# Import dependencies for designing Keras model
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense

# %%
# Design simple neural network architecture (dense = fully connected)
model = Sequential()
model.add(Dense(16, input_dim=20, activation='relu'))  #16 neuronas en la capa oculta, 20 neuronas en la capa de entrada (variables de entrada), relu con derivada = 1
model.add(Dense(12, activation='relu')) # 12 neuronas en la capa oculta, relu con derivada = 1
model.add(Dense(4, activation='softmax')) # 4 clases de salida, softmax que saca valores entre 0 y 1

# %% [markdown]
# Difference between relu and softmax
# - relu = rectified linear unit, derivate is 1 permits to avoid vanishing gradient problem
# - softmax = exponential function, derivate is 0-1, permits to normalize the output to a probability distribution

# %%
# Show model information
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 16)                336
#
#  dense_1 (Dense)             (None, 12)                204
#
#  dense_2 (Dense)             (None, 4)                 52
#
# =================================================================
# Total params: 592
# Trainable params: 592
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# The number of parameters of each layer is obtained as follows:
#
#
# *   params_dense_1 = (input_var_num + 1) * dense_1_neurons = (20 + 1) * 16 = 336
# *   params_dense_2 = (dense_1_neurons + 1) * dense_2_neurons = (16 + 1) * 12 =      204
# *   params_dense_3 = (dense_2_neurons + 1) * dense_3_neurons = (12 + 1) * 4 =      52
#
# Where +1 comes from the bias term added in each layer.

# %% [markdown]
# ## 4. Choose loss function and optimizer

# %%
# Choose loss function, optimizer and training metrics
model.compile(loss='categorical_crossentropy', # Función de pérdida para clasificación
              optimizer='adam', # Optimizador para entrenar la red (optimizar metodos, pesos, etc)
              metrics=['accuracy']) # Métrica para evaluar el entrenamiento para controlar entre los epochs

# %% [markdown]
# ## 5. Train the network

# %%
# Choose number of epochs and batch size and train the model
history = model.fit(X_train, y_train, epochs=100, batch_size=64, 
                    validation_data=(X_val, y_val))
# Out:
# Epoch 1/100
# 29/29 [==============================] - 3s 13ms/step - loss: 1.4368 - accuracy: 0.2600 - val_loss: 1.4273 - val_accuracy: 0.2350
# Epoch 2/100
# 29/29 [==============================] - 0s 5ms/step - loss: 1.3840 - accuracy: 0.3006 - val_loss: 1.3885 - val_accuracy: 0.3150
# Epoch 3/100
# 29/29 [==============================] - 0s 6ms/step - loss: 1.3443 - accuracy: 0.3344 - val_loss: 1.3525 - val_accuracy: 0.3500
# Epoch 4/100
# 29/29 [==============================] - 0s 6ms/step - loss: 1.3048 - accuracy: 0.3744 - val_loss: 1.3151 - val_accuracy: 0.3950
# Epoch 5/100
# 29/29 [==============================] - 0s 6ms/step - loss: 1.2600 - accuracy: 0.4217 - val_loss: 1.2720 - val_accuracy: 0.4350
# Epoch 6/100
# 29/29 [==============================] - 0s 5ms/step - loss: 1.2083 - accuracy: 0.4628 - val_loss: 1.2202 - val_accuracy: 0.4700
# Epoch 7/100
# 29/29 [==============================] - 0s 5ms/step - loss: 1.1459 - accuracy: 0.5022 - val_loss: 1.1587 - val_accuracy: 0.5000
# Epoch 8/100
# 29/29 [==============================] - 0s 6ms/step - loss: 1.0719 - accuracy: 0.5511 - val_loss: 1.0837 - val_accuracy: 0.5550
# Epoch 9/100
# 29/29 [==============================] - 0s 6ms/step - loss: 0.9881 - accuracy: 0.5811 - val_loss: 1.0005 - val_accuracy: 0.5700
# Epoch 10/100
# 29/29 [==============================] - 0s 6ms/step - loss: 0.9003 - accuracy: 0.6228 - val_loss: 0.9145 - val_accuracy: 0.6000
# Epoch 11/100
# 29/29 [==============================] - 0s 5ms/step - loss: 0.8146 - accuracy: 0.6706 - val_loss: 0.8252 - val_accuracy: 0.6350
# Epoch 12/100
# 29/29 [==============================] - 0s 5ms/step - loss: 0.7342 - accuracy: 0.7200 - val_loss: 0.7455 - val_accuracy: 0.6800
# Epoch 13/100
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6621 - accuracy: 0.7633 - val_loss: 0.6750 - val_accuracy: 0.7400
# Epoch 14/100
# 29/29 [==============================] - 0s 5ms/step - loss: 0.5995 - accuracy: 0.7872 - val_loss: 0.6144 - val_accuracy: 0.7600
# Epoch 15/100
# 29/29 [==============================] - 0s 6ms/step - loss: 0.5450 - accuracy: 0.8256 - val_loss: 0.5614 - val_accuracy: 0.8000
# Epoch 16/100
# 29/29 [==============================] - 0s 6ms/step - loss: 0.4985 - accuracy: 0.8444 - val_loss: 0.5136 - val_accuracy: 0.8350
# Epoch 17/100
# 29/29 [==============================] - 0s 5ms/step - loss: 0.4565 - accuracy: 0.8639 - val_loss: 0.4741 - val_accuracy: 0.8550
# Epoch 18/100
# 29/29 [==============================] - 0s 6ms/step - loss: 0.4216 - accuracy: 0.8794 - val_loss: 0.4408 - val_accuracy: 0.8600
# Epoch 19/100
# 29/29 [==============================] - 0s 6ms/step - loss: 0.3904 - accuracy: 0.8928 - val_loss: 0.4144 - val_accuracy: 0.8600
# Epoch 20/100
# 29/29 [==============================] - 0s 5ms/step - loss: 0.3638 - accuracy: 0.8956 - val_loss: 0.3903 - val_accuracy: 0.8650
# Epoch 21/100
# 29/29 [==============================] - 0s 5ms/step - loss: 0.3389 - accuracy: 0.9078 - val_loss: 0.3674 - val_accuracy: 0.8700
# Epoch 22/100
# 29/29 [==============================] - 0s 5ms/step - loss: 0.3180 - accuracy: 0.9100 - val_loss: 0.3501 - val_accuracy: 0.8950
# Epoch 23/100
# 29/29 [==============================] - 0s 6ms/step - loss: 0.3002 - accuracy: 0.9167 - val_loss: 0.3351 - val_accuracy: 0.8850
# Epoch 24/100
# 29/29 [==============================] - 0s 5ms/step - loss: 0.2827 - accuracy: 0.9228 - val_loss: 0.3186 - val_accuracy: 0.8950
# Epoch 25/100
# 29/29 [==============================] - 0s 6ms/step - loss: 0.2682 - accuracy: 0.9228 - val_loss: 0.3075 - val_accuracy: 0.9050
# Epoch 26/100
# 29/29 [==============================] - 0s 5ms/step - loss: 0.2541 - accuracy: 0.9250 - val_loss: 0.2968 - val_accuracy: 0.8850
# Epoch 27/100
# 29/29 [==============================] - 0s 5ms/step - loss: 0.2408 - accuracy: 0.9306 - val_loss: 0.2847 - val_accuracy: 0.8950
# Epoch 28/100
# 29/29 [==============================] - 0s 5ms/step - loss: 0.2303 - accuracy: 0.9350 - val_loss: 0.2746 - val_accuracy: 0.9050
# Epoch 29/100
# 29/29 [==============================] - 0s 6ms/step - loss: 0.2207 - accuracy: 0.9328 - val_loss: 0.2652 - val_accuracy: 0.9000
# Epoch 30/100
# 29/29 [==============================] - 0s 6ms/step - loss: 0.2108 - accuracy: 0.9372 - val_loss: 0.2585 - val_accuracy: 0.9050
# Epoch 31/100
# 29/29 [==============================] - 0s 6ms/step - loss: 0.2029 - accuracy: 0.9417 - val_loss: 0.2536 - val_accuracy: 0.9050
# Epoch 32/100
# 29/29 [==============================] - 0s 5ms/step - loss: 0.1940 - accuracy: 0.9433 - val_loss: 0.2464 - val_accuracy: 0.9050
# Epoch 33/100
# 29/29 [==============================] - 0s 6ms/step - loss: 0.1872 - accuracy: 0.9500 - val_loss: 0.2388 - val_accuracy: 0.9100
# Epoch 34/100
# 29/29 [==============================] - 0s 6ms/step - loss: 0.1820 - accuracy: 0.9467 - val_loss: 0.2342 - val_accuracy: 0.9150
# Epoch 35/100
# 29/29 [==============================] - 0s 5ms/step - loss: 0.1758 - accuracy: 0.9472 - val_loss: 0.2332 - val_accuracy: 0.9050
# Epoch 36/100
# 29/29 [==============================] - 0s 6ms/step - loss: 0.1696 - accuracy: 0.9506 - val_loss: 0.2237 - val_accuracy: 0.9200
# Epoch 37/100
# 29/29 [==============================] - 0s 6ms/step - loss: 0.1643 - accuracy: 0.9517 - val_loss: 0.2185 - val_accuracy: 0.9200
# Epoch 38/100
# 29/29 [==============================] - 0s 5ms/step - loss: 0.1592 - accuracy: 0.9539 - val_loss: 0.2183 - val_accuracy: 0.9200
# Epoch 39/100
# 29/29 [==============================] - 0s 6ms/step - loss: 0.1545 - accuracy: 0.9561 - val_loss: 0.2121 - val_accuracy: 0.9250
# Epoch 40/100
# 29/29 [==============================] - 0s 6ms/step - loss: 0.1502 - accuracy: 0.9600 - val_loss: 0.2110 - val_accuracy: 0.9150
# Epoch 41/100
# 29/29 [==============================] - 0s 5ms/step - loss: 0.1486 - accuracy: 0.9533 - val_loss: 0.2077 - val_accuracy: 0.9200
# Epoch 42/100
# 29/29 [==============================] - 0s 5ms/step - loss: 0.1433 - accuracy: 0.9600 - val_loss: 0.1999 - val_accuracy: 0.9300
# Epoch 43/100
# 29/29 [==============================] - 0s 6ms/step - loss: 0.1398 - accuracy: 0.9606 - val_loss: 0.1967 - val_accuracy: 0.9300
# Epoch 44/100
# 29/29 [==============================] - 0s 5ms/step - loss: 0.1364 - accuracy: 0.9589 - val_loss: 0.1977 - val_accuracy: 0.9250
# Epoch 45/100
# 29/29 [==============================] - 0s 5ms/step - loss: 0.1320 - accuracy: 0.9622 - val_loss: 0.1965 - val_accuracy: 0.9300
# Epoch 46/100
# 29/29 [==============================] - 0s 5ms/step - loss: 0.1284 - accuracy: 0.9633 - val_loss: 0.1947 - val_accuracy: 0.9300
# Epoch 47/100
# 29/29 [==============================] - 0s 5ms/step - loss: 0.1258 - accuracy: 0.9656 - val_loss: 0.1915 - val_accuracy: 0.9300
# Epoch 48/100
# 29/29 [==============================] - 0s 6ms/step - loss: 0.1248 - accuracy: 0.9611 - val_loss: 0.1896 - val_accuracy: 0.9300
# Epoch 49/100
# 29/29 [==============================] - 0s 6ms/step - loss: 0.1221 - accuracy: 0.9589 - val_loss: 0.1931 - val_accuracy: 0.9300
# Epoch 50/100
# 29/29 [==============================] - 0s 6ms/step - loss: 0.1169 - accuracy: 0.9650 - val_loss: 0.1892 - val_accuracy: 0.9250
# Epoch 51/100
# 29/29 [==============================] - 0s 6ms/step - loss: 0.1143 - accuracy: 0.9706 - val_loss: 0.1849 - val_accuracy: 0.9250
# Epoch 52/100
# 29/29 [==============================] - 0s 6ms/step - loss: 0.1112 - accuracy: 0.9678 - val_loss: 0.1867 - val_accuracy: 0.9300
# Epoch 53/100
# 29/29 [==============================] - 0s 6ms/step - loss: 0.1108 - accuracy: 0.9689 - val_loss: 0.1877 - val_accuracy: 0.9300
# Epoch 54/100
# 29/29 [==============================] - 0s 6ms/step - loss: 0.1074 - accuracy: 0.9711 - val_loss: 0.1808 - val_accuracy: 0.9350
# Epoch 55/100
# 29/29 [==============================] - 0s 5ms/step - loss: 0.1103 - accuracy: 0.9672 - val_loss: 0.1867 - val_accuracy: 0.9250
# Epoch 56/100
# 29/29 [==============================] - 0s 6ms/step - loss: 0.1034 - accuracy: 0.9711 - val_loss: 0.1820 - val_accuracy: 0.9300
# Epoch 57/100
# 29/29 [==============================] - 0s 5ms/step - loss: 0.1003 - accuracy: 0.9722 - val_loss: 0.1842 - val_accuracy: 0.9350
# Epoch 58/100
# 29/29 [==============================] - 0s 6ms/step - loss: 0.0982 - accuracy: 0.9750 - val_loss: 0.1821 - val_accuracy: 0.9350
# Epoch 59/100
# 29/29 [==============================] - 0s 5ms/step - loss: 0.0967 - accuracy: 0.9739 - val_loss: 0.1813 - val_accuracy: 0.9400
# Epoch 60/100
# 29/29 [==============================] - 0s 5ms/step - loss: 0.0944 - accuracy: 0.9750 - val_loss: 0.1800 - val_accuracy: 0.9350
# Epoch 61/100
# 29/29 [==============================] - 0s 6ms/step - loss: 0.0919 - accuracy: 0.9767 - val_loss: 0.1771 - val_accuracy: 0.9350
# Epoch 62/100
# 29/29 [==============================] - 0s 5ms/step - loss: 0.0909 - accuracy: 0.9789 - val_loss: 0.1795 - val_accuracy: 0.9350
# Epoch 63/100
# 29/29 [==============================] - 0s 5ms/step - loss: 0.0902 - accuracy: 0.9744 - val_loss: 0.1734 - val_accuracy: 0.9300
# Epoch 64/100
# 29/29 [==============================] - 0s 6ms/step - loss: 0.0874 - accuracy: 0.9789 - val_loss: 0.1764 - val_accuracy: 0.9350
# Epoch 65/100
# 29/29 [==============================] - 0s 5ms/step - loss: 0.0847 - accuracy: 0.9789 - val_loss: 0.1790 - val_accuracy: 0.9350
# Epoch 66/100
# 29/29 [==============================] - 0s 6ms/step - loss: 0.0829 - accuracy: 0.9806 - val_loss: 0.1765 - val_accuracy: 0.9350
# Epoch 67/100
# 29/29 [==============================] - 0s 6ms/step - loss: 0.0817 - accuracy: 0.9783 - val_loss: 0.1744 - val_accuracy: 0.9350
# Epoch 68/100
# 29/29 [==============================] - 0s 6ms/step - loss: 0.0800 - accuracy: 0.9811 - val_loss: 0.1763 - val_accuracy: 0.9350
# Epoch 69/100
# 29/29 [==============================] - 0s 6ms/step - loss: 0.0791 - accuracy: 0.9800 - val_loss: 0.1778 - val_accuracy: 0.9350
# Epoch 70/100
# 29/29 [==============================] - 0s 6ms/step - loss: 0.0768 - accuracy: 0.9833 - val_loss: 0.1760 - val_accuracy: 0.9350
# Epoch 71/100
# 29/29 [==============================] - 0s 6ms/step - loss: 0.0754 - accuracy: 0.9817 - val_loss: 0.1820 - val_accuracy: 0.9350
# Epoch 72/100
# 29/29 [==============================] - 0s 6ms/step - loss: 0.0773 - accuracy: 0.9794 - val_loss: 0.1805 - val_accuracy: 0.9350
# Epoch 73/100
# 29/29 [==============================] - 0s 6ms/step - loss: 0.0730 - accuracy: 0.9822 - val_loss: 0.1770 - val_accuracy: 0.9350
# Epoch 74/100
# 29/29 [==============================] - 0s 5ms/step - loss: 0.0726 - accuracy: 0.9806 - val_loss: 0.1793 - val_accuracy: 0.9350
# Epoch 75/100
# 29/29 [==============================] - 0s 5ms/step - loss: 0.0704 - accuracy: 0.9839 - val_loss: 0.1738 - val_accuracy: 0.9350
# Epoch 76/100
# 29/29 [==============================] - 0s 6ms/step - loss: 0.0693 - accuracy: 0.9856 - val_loss: 0.1745 - val_accuracy: 0.9350
# Epoch 77/100
# 29/29 [==============================] - 0s 5ms/step - loss: 0.0680 - accuracy: 0.9856 - val_loss: 0.1710 - val_accuracy: 0.9400
# Epoch 78/100
# 29/29 [==============================] - 0s 6ms/step - loss: 0.0665 - accuracy: 0.9850 - val_loss: 0.1750 - val_accuracy: 0.9350
# Epoch 79/100
# 29/29 [==============================] - 0s 6ms/step - loss: 0.0663 - accuracy: 0.9861 - val_loss: 0.1707 - val_accuracy: 0.9400
# Epoch 80/100
# 29/29 [==============================] - 0s 5ms/step - loss: 0.0644 - accuracy: 0.9878 - val_loss: 0.1727 - val_accuracy: 0.9400
# Epoch 81/100
# 29/29 [==============================] - 0s 6ms/step - loss: 0.0631 - accuracy: 0.9867 - val_loss: 0.1709 - val_accuracy: 0.9400
# Epoch 82/100
# 29/29 [==============================] - 0s 6ms/step - loss: 0.0627 - accuracy: 0.9883 - val_loss: 0.1710 - val_accuracy: 0.9400
# Epoch 83/100
# 29/29 [==============================] - 0s 5ms/step - loss: 0.0605 - accuracy: 0.9894 - val_loss: 0.1707 - val_accuracy: 0.9400
# Epoch 84/100
# 29/29 [==============================] - 0s 6ms/step - loss: 0.0615 - accuracy: 0.9872 - val_loss: 0.1705 - val_accuracy: 0.9400
# Epoch 85/100
# 29/29 [==============================] - 0s 6ms/step - loss: 0.0598 - accuracy: 0.9894 - val_loss: 0.1707 - val_accuracy: 0.9400
# Epoch 86/100
# 29/29 [==============================] - 0s 6ms/step - loss: 0.0573 - accuracy: 0.9894 - val_loss: 0.1728 - val_accuracy: 0.9400
# Epoch 87/100
# 29/29 [==============================] - 0s 6ms/step - loss: 0.0568 - accuracy: 0.9894 - val_loss: 0.1737 - val_accuracy: 0.9400
# Epoch 88/100
# 29/29 [==============================] - 0s 6ms/step - loss: 0.0551 - accuracy: 0.9917 - val_loss: 0.1726 - val_accuracy: 0.9400
# Epoch 89/100
# 29/29 [==============================] - 0s 5ms/step - loss: 0.0551 - accuracy: 0.9911 - val_loss: 0.1768 - val_accuracy: 0.9350
# Epoch 90/100
# 29/29 [==============================] - 0s 5ms/step - loss: 0.0537 - accuracy: 0.9900 - val_loss: 0.1747 - val_accuracy: 0.9400
# Epoch 91/100
# 29/29 [==============================] - 0s 5ms/step - loss: 0.0536 - accuracy: 0.9917 - val_loss: 0.1680 - val_accuracy: 0.9400
# Epoch 92/100
# 29/29 [==============================] - 0s 5ms/step - loss: 0.0522 - accuracy: 0.9900 - val_loss: 0.1711 - val_accuracy: 0.9350
# Epoch 93/100
# 29/29 [==============================] - 0s 6ms/step - loss: 0.0513 - accuracy: 0.9917 - val_loss: 0.1749 - val_accuracy: 0.9400
# Epoch 94/100
# 29/29 [==============================] - 0s 6ms/step - loss: 0.0503 - accuracy: 0.9933 - val_loss: 0.1752 - val_accuracy: 0.9350
# Epoch 95/100
# 29/29 [==============================] - 0s 5ms/step - loss: 0.0496 - accuracy: 0.9917 - val_loss: 0.1721 - val_accuracy: 0.9350
# Epoch 96/100
# 29/29 [==============================] - 0s 6ms/step - loss: 0.0476 - accuracy: 0.9939 - val_loss: 0.1742 - val_accuracy: 0.9400
# Epoch 97/100
# 29/29 [==============================] - 0s 5ms/step - loss: 0.0477 - accuracy: 0.9911 - val_loss: 0.1756 - val_accuracy: 0.9350
# Epoch 98/100
# 29/29 [==============================] - 0s 5ms/step - loss: 0.0472 - accuracy: 0.9922 - val_loss: 0.1754 - val_accuracy: 0.9350
# Epoch 99/100
# 29/29 [==============================] - 0s 5ms/step - loss: 0.0460 - accuracy: 0.9922 - val_loss: 0.1742 - val_accuracy: 0.9350
# Epoch 100/100
# 29/29 [==============================] - 0s 6ms/step - loss: 0.0452 - accuracy: 0.9928 - val_loss: 0.1771 - val_accuracy: 0.9350

# %%
# Import dependence for plotting training process 
import matplotlib.pyplot as plt

# %%
# Plot training and validation accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

# %%
# Plot training and test loss
plt.plot(history.history['loss']) 
plt.plot(history.history['val_loss']) 
plt.title('Model loss') 
plt.ylabel('Loss')
plt.xlabel('Epoch') 
plt.legend(['Train', 'Val'], loc='upper left') 
plt.show()

# %%
# Save the model
from pathlib import Path
path = Path('./models')
if not path.exists():
  path.mkdir()
model.save('./models/model_1.h5')

# %%
# List files of ./models directory
# !ls ./models
# Out:
# model_1.h5

# %% [markdown]
# # Exercise 1: Train the model without normalization

# %%
# Split data without normalization in training and validation partitions

# %%
# Train the model

# %%
# Plot training and validation accuracy

# %%
# Plot training and test loss

# %% [markdown]
# # Exercise 2: Train a simpler model and evaluate the results

# %%
# Split data with normalization in training and validation partitions

# %%
# Design a model like the previous but without the second Dense layer

# %%
# Compile the model

# %%
# Train the model

# %%
# Plot training and validation accuracy

# %%
# Plot training and test loss

# %% [markdown]
# # Exercise 3: Train a more complex model and evaluate the results

# %%
# Split data with normalization in training and validation partitions

# %%
# Design a model like the previous but with 128 neurons in the first Dense layer
# and 256 in the second

# %%
# Compile the model

# %%
# Train the model

# %%
# Plot training and validation accuracy

# %%
# Plot training and test loss

# %% [markdown]
# # Exercise 4: Predict the price range of the phones of the test.csv file

# %%
# Read it test data from csv

# %%
# Show column names (pay attention, maybe there is something different)

# %%
# Convert the data to numpy array

# %%
# Show shape of the data

# %%
# Get rid of a column if needed

# %%
# Normalize data. Important!! Always normalize test data with the mean and
# standard deviation learnt from the training data.

# %%
# Show data before and after normalization

# %%
# Load model saved during the example
from keras.models import load_model
model = load_model('./models/model_1.h5')

# %%
# Predict price range
predictions = model.predict(data_norm)

# %%
# Show predictions

# %%
# Convert predictions to scalars from one-hot encoding

# %%
# Show all scalar predictions

# %%
# Show the first test sample in Dataframe format

# %%
# Show prediction for that sample
